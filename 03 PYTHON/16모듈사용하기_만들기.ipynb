# %% [markdown]
# # 모듈 사용하기
# * 누군가가 미리 사용하기 편하게 만들어 놓은 함수, 클래스
# * import 명령을 통해서 프로그램 가장 위에서 모듈을 불러와 사용할 수 있다.
# * 모듈에 너무 많은 기능이 있는 경우 from 모듈명 import 함수/메소드명 형식으로 일부 기능만 불러올 수도 있음
# * 모듈은 사용자가 직접 만들수도 있음
# * 사용자 모듈을 불러올 때는 실행하는 파일과 같은 위치에 있어야 함

# %% [markdown]
# # datetime 모듈 사용하기

# %%
from datetime import datetime

# %%
datetime.now()
# Out:
# datetime.datetime(2025, 3, 28, 16, 28, 17, 11653)

# %%
now = datetime.now()

# %%
now.year
# Out:
# 2025

# %%
now.month
# Out:
# 3

# %%
now.minute
# Out:
# 28

# %%
now.second
# Out:
# 57

# %% [markdown]
# 시간을 포멧에 맞춰 출력하기

# %%
now.strftime("%Y.%m.%d %H:%M:%S")
# Out:
# '2025.03.28 16:28:57'

# %% [markdown]
# # OS 모듈

# %%
import os

# %%
# 내가 사용하는 컴퓨터의 기본정보 출력하기
print("현재 운영체제: ", os.name)
print("현재 사용하는 폴더: ", os.getcwd())
print("현재 폴더 내부의 파일 리스트: ", os.listdir())
# Out:
# 현재 운영체제:  nt
# 현재 사용하는 폴더:  C:\fintech\03 PYTHON
# 현재 폴더 내부의 파일 리스트:  ['.ipynb_checkpoints', '01주피터노트북사용법.ipynb', '02파이썬문법기초.ipynb', '03파이썬의_자료형.ipynb', '04연산자_종류_활용.ipynb', '05문자열과_문자열함수.ipynb', '06리스트와_튜플_사용하기.ipynb', '07딕셔너리_사용하기.ipynb', '08서식지정자와_문자열_포멧팅.ipynb', '09if_elif_else조건문.ipynb', '10반복문_for_while.ipynb', '11리스트표현식_파일읽기쓰기.ipynb', '12JSON데이터언패킹해서CSV파일로만들기.ipynb', '13함수만들기_예외처리.ipynb', '14JSON언패킹2_호텔스닷컴리뷰_자료정리하기.ipynb', '15클래스만들기.ipynb', '16모듈사용하기_만들기.ipynb', 'cmd 명령어 정리.txt', 'data', 'test.txt', 'test2.txt', 'test_utf-8.txt', 'wikidocs_001~040.ipynb', 'wikidocs_041~070.ipynb', 'wikidocs_071~080.ipynb', '연습문제_01_print_자료형_연산자-풀이.ipynb', '연습문제_01_print_자료형_연산자.ipynb', '연습문제_02_문자열_리스트.ipynb', '연습문제_03_리스트_튜플_20문제.ipynb', '연습문제_04_딕셔너리_30문제.ipynb', '연습문제_05_딕셔너리_조건문_반복문연습문제.ipynb', '호텔스닷컴리뷰.csv', '호텔정보.csv']

# %%
files = []
for file_name in os.listdir():
    print(i)
    if file_name[-3:] == "txt":
        print(i)
        with open(file_name, encoding="utf-8") as file:
            data = file.read()
            files.append(data)
# Out:
# 호텔정보.csv
# 호텔정보.csv
# 호텔정보.csv
# 호텔정보.csv
# 호텔정보.csv
# 호텔정보.csv
# 호텔정보.csv
# 호텔정보.csv
# 호텔정보.csv
# 호텔정보.csv
# 호텔정보.csv
# 호텔정보.csv
# 호텔정보.csv
# 호텔정보.csv
# 호텔정보.csv
# 호텔정보.csv
# 호텔정보.csv
# 호텔정보.csv
# 호텔정보.csv
# 호텔정보.csv
# 호텔정보.csv
# 호텔정보.csv
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[21], line 7
#       5 print(i)
#       6 with open(file_name, encoding="utf-8") as file:
# ----> 7     data = file.read()
#       8     files.append(data)
#
# File ~\miniforge3\envs\fintech\lib\codecs.py:322, in BufferedIncrementalDecoder.decode(self, input, final)
#     319 def decode(self, input, final=False):
#     320     # decode input (taking the buffer into account)
#     321     data = self.buffer + input
# --> 322     (result, consumed) = self._buffer_decode(data, self.errors, final)
#     323     # keep undecoded input until the next call
#     324     self.buffer = data[consumed:]
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xc6 in position 0: invalid continuation byte

# %%
files
# Out:
# ['가상환경 = 폴더를 만드는 것\n콘다 활성화 : conda activate 가상환경명\n가상환경 만들기 : conda create -n 가상환경명 python=버전\n패키지 설치 : conda install 패키지명\n설치된 패키기 목록 보기 : conda list\n가상환경 목록 보기 : conda info --envs\n가상환경 삭제하기 : conda remove -n 가상환경명 --all\njupyter notebook 작업 폴더 설정\njupyter notebook --generate config\njupyter_notebook_config.py 파일열기\n_dir에서 경로 바꾸기\n\n']

# %%
# 현재 위치에서 폴더 만들기
os.mkdir("testdir")

# %%
# 현재 위치에서 폴더 삭제하기
os.rmdir("testdir")

# %%
# cmd 명령어 실행하기
os.system("dir")
# Out:
# 0

# %%
# 파일을 생성하고 파일이름 변경하기
with open("original.txt", "w") as file:
    file.write("안녕하세요")

# %%
os.rename("original.txt", "new.txt")

# %%
# 폴더가 있는지 확인하고 없으면 폴더 생성하기
if not os.path.exists("./testdir"):
    os.mkdir("testdir")
else:
    print("testdir이 이미 있습니다.")
# Out:
# testdir이 이미 있습니다.

# %%
# 환경변수
os.environ["key"] = "value"
print(os.environ.get("key"))
# Out:
# value

# %%
print(os.environ.get("Path"))
# Out:
# C:\Users\Admin\miniforge3\envs\fintech;C:\Users\Admin\miniforge3\envs\fintech\Library\mingw-w64\bin;C:\Users\Admin\miniforge3\envs\fintech\Library\usr\bin;C:\Users\Admin\miniforge3\envs\fintech\Library\bin;C:\Users\Admin\miniforge3\envs\fintech\Scripts;C:\Users\Admin\miniforge3\envs\fintech\bin;C:\Users\Admin\miniforge3\condabin;C:\Windows\system32;C:\Windows;C:\Windows\System32\Wbem;C:\Windows\System32\WindowsPowerShell\v1.0;C:\Windows\System32\OpenSSH;C:\Program Files\Bandizip;C:\Program Files\Git\cmd;C:\Users\Admin\AppData\Local\Microsoft\WindowsApps;C:\Users\Admin\AppData\Local\Programs\Microsoft VS Code\bin

# %%
from myfunc import *

# %%
add(3,4)
# Out:
# 7

# %%
sam = Cal(3, 4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 sam = Cal(3, 4)
#
# TypeError: Cal() takes no arguments
