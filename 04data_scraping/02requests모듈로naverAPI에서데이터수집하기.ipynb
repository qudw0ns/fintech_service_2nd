# %% [markdown]
# # 1.requests 모듈 : http 프로토콜을 사용할 수 있게 해주는 모듈
# * requests 모듈 사용설명서
# [requests](https://requests.readthedocs.io/en/latest/)

# %% [markdown]
# # 3. requests 모듈 사용법
#
# * 1) 모듈 불러오기 : import requests
# * 2) url 변수에 저장
# * 3) url parameter
#      * payload = {파라미터1 : value, 파라미터2 : value}
# * 4) headers
#      * headers = {key : value}
# * 5) http 요청 보내기 get, post
#      * get : r = requests.get(url, params=payload, headers=headers)
#      * post : r = requests.post(url, data={key:value})
# * 6) 만들어진 url 확인 : print(r.url)
# * 7) 응답코드 확인 : print(r.status_code)
# * 8) 응답 요소 출력 : r.text, r.content, r.json()

# %%
startnum2 = 1
for s_num in range(11):
    if startnum2 < 901:
        print(startnum2)
        startnum2 += 100
    elif startnum2 == 901:
        print(startnum2)
        startnum2 += 99
        print(startnum2)
# Out:
# 1
# 101
# 201
# 301
# 401
# 501
# 601
# 701
# 801
# 901
# 1000

# %%
import requests
start_num = 1
result_json = []
for page in range(11):
    url = "https://openapi.naver.com/v1/search/blog"
    payload = {'query': '핀테크', 'display': 100, 'start': start_num, 'sort': "sim"}
    headers = {"X-Naver-Client-Id" : "YYIYgjstxPdUpH7WXuUE", "X-Naver-Client-Secret" : "wqrbMV9nRh"}
    r = requests.get(url, params=payload, headers=headers)
    print(r.url)
    print(r.status_code)
    data = r.json()
    result_json.append(data)
    if start_num < 901:
        start_num += 100
    elif start_num == 901:
        start_num += 99
# Out:
# https://openapi.naver.com/v1/search/blog?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=1&sort=sim
# 200
# https://openapi.naver.com/v1/search/blog?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=101&sort=sim
# 200
# https://openapi.naver.com/v1/search/blog?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=201&sort=sim
# 200
# https://openapi.naver.com/v1/search/blog?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=301&sort=sim
# 200
# https://openapi.naver.com/v1/search/blog?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=401&sort=sim
# 200
# https://openapi.naver.com/v1/search/blog?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=501&sort=sim
# 200
# https://openapi.naver.com/v1/search/blog?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=601&sort=sim
# 200
# https://openapi.naver.com/v1/search/blog?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=701&sort=sim
# 200
# ...

# %%
pages = data["total"] // data["display"] +1
pages
# Out:
# 4562

# %%
start_num = 1
response_json2 = []
for page in range(pages):
    import requests
    url = "https://openapi.naver.com/v1/search/blog"
    payload = {'query': '핀테크', 'display': 100, 'start': start_num, 'sort': "sim"}
    headers = {"X-Naver-Client-Id" : "YYIYgjstxPdUpH7WXuUE", "X-Naver-Client-Secret" : "wqrbMV9nRh"}
    r = requests.get(url, params=payload, headers=headers)
    print(r.url)
    print(r.status_code)
    data = r.json()
    response_json2.append(data)
    if start_num == 1000:
        break
    if start_num < 901:
        start_num += 100
    elif start_num == 901:
        start_num += 99
# Out:
# https://openapi.naver.com/v1/search/blog?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=1&sort=sim
# 200
# https://openapi.naver.com/v1/search/blog?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=101&sort=sim
# 200
# https://openapi.naver.com/v1/search/blog?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=201&sort=sim
# 200
# https://openapi.naver.com/v1/search/blog?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=301&sort=sim
# 200
# https://openapi.naver.com/v1/search/blog?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=401&sort=sim
# 200
# https://openapi.naver.com/v1/search/blog?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=501&sort=sim
# 200
# https://openapi.naver.com/v1/search/blog?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=601&sort=sim
# 200
# https://openapi.naver.com/v1/search/blog?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=701&sort=sim
# 200
# ...

# %% [markdown]
# # While True로 전체데이터 가져오기

# %%
page = 1
start_num2 = 1
response_json3 = []
while True:
    import requests
    url = "https://openapi.naver.com/v1/search/blog"
    payload = {'query': '핀테크', 'display': 100, 'start': start_num2, 'sort': "sim"}
    headers = {"X-Naver-Client-Id" : "YYIYgjstxPdUpH7WXuUE", "X-Naver-Client-Secret" : "wqrbMV9nRh"}
    r = requests.get(url, params=payload, headers=headers)
    print(r.url)
    print(r.status_code)
    data = r.json()
    total_pages = (data["total"] // 100) +1
    response_json3.append(data)
    if start_num2 == 1000:
        break
    if start_num2 < 901:
        start_num2 += 100
    elif start_num2 == 901:
        start_num2 += 99
    if page <total_pages:
        page += 1
    else:
        break
print(len(response_json3))
# Out:
# https://openapi.naver.com/v1/search/blog?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=1&sort=sim
# 200
# https://openapi.naver.com/v1/search/blog?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=101&sort=sim
# 200
# https://openapi.naver.com/v1/search/blog?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=201&sort=sim
# 200
# https://openapi.naver.com/v1/search/blog?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=301&sort=sim
# 200
# https://openapi.naver.com/v1/search/blog?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=401&sort=sim
# 200
# https://openapi.naver.com/v1/search/blog?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=501&sort=sim
# 200
# https://openapi.naver.com/v1/search/blog?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=601&sort=sim
# 200
# https://openapi.naver.com/v1/search/blog?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=701&sort=sim
# 200
# ...

# %% [markdown]
# # 블로그, 책, 뉴스 동시에 수집하기

# %%
import time
response_json3 = []
for category in ["blog", "news", "book"]:
    page = 1
    start_num2 = 1
    while True:
        url = f"https://openapi.naver.com/v1/search/{category}"
        payload = {'query': '핀테크', 'display': 100, 'start': start_num2, 'sort': "sim"}
        headers = {"X-Naver-Client-Id" : "YYIYgjstxPdUpH7WXuUE", "X-Naver-Client-Secret" : "wqrbMV9nRh"}
        r = requests.get(url, params=payload, headers=headers)
        print(r.url)
        print(r.status_code)
        data = r.json()
        total_pages = (data["total"] // 100) +1
        response_json3.append(data)
        if start_num2 == 1000:
            break
        if start_num2 < 901:
            start_num2 += 100
        elif start_num2 == 901:
            start_num2 += 99
            
        if page <total_pages:
            page += 1
        else:
            break
        time.sleep(0.5)
print(len(response_json3))
# Out:
# https://openapi.naver.com/v1/search/blog?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=1&sort=sim
# 200
# https://openapi.naver.com/v1/search/blog?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=101&sort=sim
# 200
# https://openapi.naver.com/v1/search/blog?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=201&sort=sim
# 200
# https://openapi.naver.com/v1/search/blog?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=301&sort=sim
# 200
# https://openapi.naver.com/v1/search/blog?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=401&sort=sim
# 200
# https://openapi.naver.com/v1/search/blog?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=501&sort=sim
# 200
# https://openapi.naver.com/v1/search/blog?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=601&sort=sim
# 200
# https://openapi.naver.com/v1/search/blog?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=701&sort=sim
# 200
# ...

# %% [markdown]
# # 블로그, 뉴스, 책 데이터 각각 저장하기

# %%
import time
data_blog = []
data_news = []
data_book = []
keyward = input("검색할 키워드를 입력하세요.")
for category in ["blog", "news", "book"]:
    page = 1
    start_num2 = 1
    while True:
        url = (f"https://openapi.naver.com/v1/search/{category}.json")
        payload = {'query': 'keward', 'display': 100, 'start': start_num2, 'sort': "sim"}
        headers = {"X-Naver-Client-Id" : "YYIYgjstxPdUpH7WXuUE", "X-Naver-Client-Secret" : "wqrbMV9nRh"}
        r = requests.get(url, params=payload, headers=headers)
        data = r.json()
        total_pages = (data["total"] // 100) +1
        
        if category == "blog":
            data_blog.append(data)
        elif category == "news":
            data_news.append(data)
        elif category == "book":
            data_book.append(data)
            
        if start_num2 == 1000:
            break
        if start_num2 < 901:
            start_num2 += 100
        elif start_num2 == 901:
            start_num2 += 99
            
        if page <total_pages:
            page += 1
        else:
            break
        time.sleep(0.5)
# Out:
# 검색할 키워드를 입력하세요.핀테크

# %%
import requests
import pandas as pd

# %%
def json_unpack(all_data):
    final_result = {}
    for page in all_data:
        for item in page['items']:
            for key, value in item.items():
                final_result_blog.setdefault(key, []).append(value)

    df = pd.DataFrame(final_result)
    return df

# %%
for jsons, cat in zip([data_blog, data_news, data_book]):
    unpack_result = json_unpack(jsons)
    unpack_result.to_csv(f"naver_{cat}_result.csv", encoding="utf-8", index=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 for jsons, cat in zip([data_blog, data_news, data_book]):
#       2     unpack_result = json_unpack(jsons)
#       3     unpack_result.to_csv(f"naver_{cat}_result.csv", encoding="utf-8", index=False)
#
# ValueError: not enough values to unpack (expected 2, got 1)

# %% [markdown]
# # 3개 카테고리 수집 코드를 함수화하기

# %%
def naver_search(category):
    data_result = []
    page = 1
    start_num2 = 1
    while True:
        url = (f"https://openapi.naver.com/v1/search/{category}.json")
        payload = {'query': 'keward', 'display': 100, 'start': start_num2, 'sort': "sim"}
        headers = {"X-Naver-Client-Id" : "YYIYgjstxPdUpH7WXuUE", "X-Naver-Client-Secret" : "wqrbMV9nRh"}
        r = requests.get(url, params=payload, headers=headers)
        data = r.json()
        total_pages = (data["total"] // 100) +1
        
        data_result.append(data)
            
        if start_num2 == 1000:
            break
        if start_num2 < 901:
            start_num2 += 100
        elif start_num2 == 901:
            start_num2 += 99
            
        if page <total_pages:
            page += 1
        else:
            break
        time.sleep(0.5)
        
    return data_result

# %%
import time
keyward = input("검색할 키워드를 입력하세요.")
for category in ["blog", "news", "book"]:
    naver_search_result = naver_search(category)
    print(f"{category}_search_result: {len(naver_search_result)}")
# Out:
# 검색할 키워드를 입력하세요.인공지능
# blog_search_result: 1
# news_search_result: 1
# book_search_result: 1

# %%
payload
# Out:
# {'query': '핀테크', 'display': 100, 'start': 1, 'sort': 'sim'}

# %%
headers
# Out:
# {'X-Naver-Client-Id': 'YYIYgjstxPdUpH7WXuUE',
#  'X-Naver-Client-Secret': 'wqrbMV9nRh'}

# %% [markdown]
# * 모든 검색결과를 가져오기 위해서는 여러 페이지 정보를 수집
# * 전체 결과 / 1페이지 표시 개수 = 전체 페이지 수
# * start 부분 + 1페이지 표시 개수 = 다음 페이지 데이터 수집 가능
# * 반복문을 이용해서 start에 100씩 더해서 최대 1000이 되도록 하면 최대한 많은 데이터 수집 가능

# %% [markdown]
# 네이버 검색 API를 이용해서 책을 검색하고 결과를 데이터프레임으로 만드세요.
# * 검색어는 input()을 이용해서 입력받은 값을 이용하세요.

# %%
import requests
url = "https://openapi.naver.com/v1/search/book.json"
book = input("책 제목을 입력하세요")
payload = {'query': book, 'display': 100, 'start': 1, 'sort': "sim"}
headers = {"X-Naver-Client-Id" : "YYIYgjstxPdUpH7WXuUE", "X-Naver-Client-Secret" : "wqrbMV9nRh"}
r = requests.get(url, params=payload, headers=headers)
print(r.url)
print(r.status_code)
data = r.json()
data
# Out:
# 책 제목을 입력하세요파이썬
# https://openapi.naver.com/v1/search/book.json?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC&display=100&start=1&sort=sim
# 200
# {'lastBuildDate': 'Mon, 31 Mar 2025 17:12:52 +0900',
#  'total': 1113,
#  'start': 1,
#  'display': 100,
#  'items': [{'title': '혼자 만들면서 공부하는 파이썬 (37개 라이브러리와 API로 보고서, 차트, 게임, 맵, AI 챗봇 만들기|저자 직강 유튜브 강의, 오픈 채팅 제공)',
#    'link': 'https://search.shopping.naver.com/book/catalog/52859338841',
#    'image': 'https://shopping-phinf.pstatic.net/main_5285933/52859338841.20250209071357.jpg',
#    'author': '문현일',
#    'discount': '23400',
#    'publisher': '한빛미디어',
#    'pubdate': '20250214',
#    'isbn': '9791169213271',
# ...

# %%
def json_unpack(data):
    result = {}
    for item in data["items"]:
        for key, value in item.items():
            result.setdefault(key, []).append(value)
    result
    import pandas as pd
    df = pd.DataFrame(result)
    return df

# %%
import requests
url = "https://openapi.naver.com/v1/search/book.json"
book = input("책 제목을 입력하세요")
payload = {'query': book, 'display': 100, 'start':1000 , 'sort':'sim'}
headers = {"X-Naver-Client-Id":"YYIYgjstxPdUpH7WXuUE", "X-Naver-Client-Secret":"wqrbMV9nRh"}
r = requests.get(url, params=payload, headers=headers)
print(r.url)
print(r.status_code)
data = r.json()
print("전체 검색 데이터 수 :", data["total"], "검색할 페이지수:", (int(data["total"])//100)+1)
# Out:
# 책 제목을 입력하세요파이썬
# https://openapi.naver.com/v1/search/book.json?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC&display=100&start=1000&sort=sim
# 200
# 전체 검색 데이터 수 : 1113 검색할 페이지수: 12

# %%
result_df = json_unpack(data)
result_df
# Out:
#                                                 title  \
# 0   파이썬과 케라스를 이용한 딥러닝/강화학습 주식투자 (퀀트 투자 알고리즘 트레이딩을 ...
# 1   슬기로운 코딩 생활 with 파이썬 으랏차차 기초편 (즐겁게 시작하고 똑똑하게 끝내...
# 2   2024 내일은 빅데이터분석기사 실기 with 파이썬 (제6회부터 변경된 작업형 제...
# 3   2024 빅데이터분석기사 실기 한권완성: 파이썬(Python) (작업형 제3유형 완...
# 4   Step by Step CRM을 위한 파이썬 머신러닝 (빅 데이터 분석 자격증 머신...
# ..                                                ...
# 95  챗GPT와 업무자동화 (1분 만에 끝내는 엑셀, 구글 시트, 파워포인트, 파이썬 자...
# 96  프로그래밍 정석(개념을 잡아주는) (기초 연산부터 고급 문제해결 능력까지 파이썬을 ...
# 97  머신러닝 딥러닝을 이용한 A.I. 자율주행 RC카 프로젝트 with 파이썬+아두이노...
# 98         파이썬 딥러닝 파이토치(Python Deep Learning PyTorch)
# 99  Let’s Start Coding with Raptor & Python (랩터 & ...
#
#                                                  link  \
# 0   https://search.shopping.naver.com/book/catalog...
# 1   https://search.shopping.naver.com/book/catalog...
# 2   https://search.shopping.naver.com/book/catalog...
# 3   https://search.shopping.naver.com/book/catalog...
# ...

# %% [markdown]
# # 네이버 API로 검색한 결과 최대한 가져오기
# * 1회 네이버 서버에 요청
# * 응답에서 total을 찾아서 dispalay로 나누어 총 반복할 페이지 산출
# * 반복문 작성 및 종료 조건 설정
# * 1페이지 결과를 데이터 프레임으로 만들고 리스트에 append
# * 반복이 끝난 후 리스트에 append된 데이터 프레임을 1개로 합침

# %% [markdown]
# # for문을 이용해서 전체 페이지 가져오기

# %%
keyword = input("검색할 키워드를 입력해 주세요: ")
# Out:
# 검색할 키워드를 입력해 주세요: 파이썬

# %%
all_data = []

# %%
url = "https://openapi.naver.com/v1/search/book.json"
Client_Id = "YYIYgjstxPdUpH7WXuUE"
Client_Secret = "wqrbMV9nRh"
headers = {"X-Naver-Client-Id" : Client_Id, "X-Naver-Client-Secret" : Client_Secret}
payload = dict(query=keyword, display=100, start=1, sort="sim")
r = requests.get(url, params=payload, headers=headers)
print(r.url)
print(r.status_code)
data = r.json()
n_data = data['total']
total_pages = (int(data['total'])//100)+1
print("전체 검색 데이터 수: ", n_data, "검색할 페이지수: ", total_pages )
result_df = json_unpack(data)
all_data.append(result_df)
# Out:
# https://openapi.naver.com/v1/search/book.json?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC&display=100&start=1&sort=sim
# 200
# 전체 검색 데이터 수:  1113 검색할 페이지수:  12

# %%
start = 101
for page in range(total_pages):
    print(f"{page+1}/{total_pages} 수집중", end="\r")
    url = "https://openapi.naver.com/v1/search/book.json"
    Client_Id = "sk2iKdMANqpvG3Pa2WIJ"
    Client_Secret = "by6xHZcrlB"
    headers = {"X-Naver-Client-Id" : Client_Id, "X-Naver-Client-Secret" : Client_Secret}
    payload = dict(query=keyword, display=100, start=start, sort="sim")
    r = requests.get(url, params=payload, headers=headers)
    print(r.url)
    print(r.status_code)
    data = r.json()
    n_data = data['total']
    total_pages = (int(data['total'])//100)+1
#     print("전체 검색 데이터 수: ", n_data, "검색할 페이지수: ", total_pages )
    result_df = json_unpack(data)
    all_data.append(result_df)
    if start == 1000:
        break
    elif start < 901:
        start += 100
    elif start == 901:
        start += 99
# Out:
# https://openapi.naver.com/v1/search/book.json?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC&display=100&start=101&sort=sim
# 200
# https://openapi.naver.com/v1/search/book.json?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC&display=100&start=201&sort=sim
# 200
# https://openapi.naver.com/v1/search/book.json?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC&display=100&start=301&sort=sim
# 200
# https://openapi.naver.com/v1/search/book.json?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC&display=100&start=401&sort=sim
# 200
# https://openapi.naver.com/v1/search/book.json?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC&display=100&start=501&sort=sim
# 200
# https://openapi.naver.com/v1/search/book.json?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC&display=100&start=601&sort=sim
# 200
# https://openapi.naver.com/v1/search/book.json?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC&display=100&start=701&sort=sim
# 200
# https://openapi.naver.com/v1/search/book.json?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC&display=100&start=801&sort=sim
# 200
# ...

# %%
len(all_data)
# Out:
# 11

# %%
import pandas as pd

# %%
final_result = pd.concat(all_data)
final_result = final_result.reset_index(drop=True)
final_result
# Out:
#                                                   title  \
# 0     혼자 만들면서 공부하는 파이썬 (37개 라이브러리와 API로 보고서, 차트, 게임,...
# 1                  혼자 공부하는 파이썬 (1:1 과외하듯 배우는 프로그래밍 자습서)
# 2              Do it! 점프 투 파이썬 (중학생도 첫날부터 실습하는 초고속 입문서)
# 3        밑바닥부터 시작하는 딥러닝 1(리마스터판) (파이썬으로 익히는 딥러닝 이론과 구현)
# 4     50개의 프로젝트로 완성하는 파이썬 업무 자동화 (프로젝트 따라하기로 업무 자동화 ...
# ...                                                 ...
# 1095  챗GPT와 업무자동화 (1분 만에 끝내는 엑셀, 구글 시트, 파워포인트, 파이썬 자...
# 1096  프로그래밍 정석(개념을 잡아주는) (기초 연산부터 고급 문제해결 능력까지 파이썬을 ...
# 1097  머신러닝 딥러닝을 이용한 A.I. 자율주행 RC카 프로젝트 with 파이썬+아두이노...
# 1098         파이썬 딥러닝 파이토치(Python Deep Learning PyTorch)
# 1099  Let’s Start Coding with Raptor & Python (랩터 & ...
#
#                                                    link  \
# 0     https://search.shopping.naver.com/book/catalog...
# 1     https://search.shopping.naver.com/book/catalog...
# 2     https://search.shopping.naver.com/book/catalog...
# 3     https://search.shopping.naver.com/book/catalog...
# ...

# %% [markdown]
# # While 문으로 데이터 모두 가져오기

# %%
import requests
import pandas as pd

# %%
keyword = input("검색 키워드를 입력해 주세요. ")
# Out:
# 검색 키워드를 입력해 주세요. 핀테크

# %%
all_data2 = []
start = 1

while True:
    url = "https://openapi.naver.com/v1/search/book.json"
    Client_Id = "sk2iKdMANqpvG3Pa2WIJ"
    Client_Secret = "by6xHZcrlB"
    headers = {"X-Naver-Client-Id" : Client_Id, "X-Naver-Client-Secret" : Client_Secret}
    payload = dict(query=keyword, display=100, start=start, sort="sim")
    r = requests.get(url, params=payload, headers=headers)
    print(r.url)
    print(r.status_code)
    data = r.json()
    n_data = data['total']
    total_pages = (int(data['total'])//100)+1
    print("전체 검색 데이터 수: ", n_data, "검색할 페이지수: ", total_pages )
    result_df = json_unpack(data)
    all_data2.append(result_df)
    if start == 1000:
        break
    elif start < 901:
        start += 100
    elif start == 901:
        start += 99
# Out:
# https://openapi.naver.com/v1/search/book.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=1&sort=sim
# 200
# 전체 검색 데이터 수:  106 검색할 페이지수:  2
# https://openapi.naver.com/v1/search/book.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=101&sort=sim
# 200
# 전체 검색 데이터 수:  106 검색할 페이지수:  2
# https://openapi.naver.com/v1/search/book.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=201&sort=sim
# 200
# 전체 검색 데이터 수:  106 검색할 페이지수:  2
# https://openapi.naver.com/v1/search/book.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=301&sort=sim
# 200
# 전체 검색 데이터 수:  106 검색할 페이지수:  2
# https://openapi.naver.com/v1/search/book.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=401&sort=sim
# 200
# 전체 검색 데이터 수:  106 검색할 페이지수:  2
# https://openapi.naver.com/v1/search/book.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=501&sort=sim
# 200
# 전체 검색 데이터 수:  106 검색할 페이지수:  2
# ...

# %%
len(all_data2)
# Out:
# 11

# %%
final_result2 = pd.concat(all_data2)
final_result2 = final_result2.reset_index(drop=True)
final_result2
# Out:
#                                                  title  \
# 0                                                  핀테크
# 1                             핀테크 (IT와 금융이 만나는 새로운 세상)
# 2                             핀테크 4.0 (핀테크 혁명과 금융의 미래)
# 3                                         핀테크와 법 (제3판)
# 4           핀테크 전쟁 (세계 금융 시장의 거대한 트렌드 | 새로운 돈의 시대가 온다)
# ..                                                 ...
# 101  신남방 지역 주요국의 핀테크 발전과 협력방안: 인도, 태국, 말레이시아, 베트남, ...
# 102  [CD] 2018 4차산업 기업.스타트업 주소록 - CD-ROM 1장 (가상현실·드...
# 103  4차산업 기업·스타트업 주소록(2023)(CD) (IOT, VR, 가상현실, 블록체...
# 104  4차산업 기업·스타트업 주소록(2024)(CD) (3D프린터, IOT, VR, 가상...
# 105  전국 체험마을 주소록(2024)(CD) (3D프린터, IOT, VR, 가상현실, 드...
#
#                                                   link  \
# 0    https://search.shopping.naver.com/book/catalog...
# 1    https://search.shopping.naver.com/book/catalog...
# 2    https://search.shopping.naver.com/book/catalog...
# 3    https://search.shopping.naver.com/book/catalog...
# ...

# %%
final_result2.to_csv("네이버검색_책_파이썬.csv", encoding="utf-8-sig", index=False)

# %% [markdown]
# # 뉴스, 블로그, 책 한번에 검색해서 저장하기

# %%
all_data3 = []

for category in ["blog", "news", "book"]:
    start = 1
    while True:
        url = f"https://openapi.naver.com/v1/search/{category}.json"
        Client_Id = "sk2iKdMANqpvG3Pa2WIJ"
        Client_Secret = "by6xHZcrlB"
        headers = {"X-Naver-Client-Id" : Client_Id, "X-Naver-Client-Secret" : Client_Secret}
        payload = dict(query=keyword, display=100, start=start, sort="sim")
        r = requests.get(url, params=payload, headers=headers)
        print(r.url)
        print(r.status_code)
        data = r.json()
        n_data = data['total']
        total_pages = (int(data['total'])//100)+1
        print("전체 검색 데이터 수: ", n_data, "검색할 페이지수: ", total_pages )
        result_df = json_unpack(data)
        all_data3.append(result_df)
        if start == 1000:
            break
        elif start < 901:
            start += 100
        elif start == 901:
            start += 99
final_result3 = pd.concat(all_data3)
final_result3 = final_result3.reset_index(drop=True)
final_result3
# Out:
# https://openapi.naver.com/v1/search/blog.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=1&sort=sim
# 200
# 전체 검색 데이터 수:  456162 검색할 페이지수:  4562
# https://openapi.naver.com/v1/search/blog.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=101&sort=sim
# 200
# 전체 검색 데이터 수:  456162 검색할 페이지수:  4562
# https://openapi.naver.com/v1/search/blog.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=201&sort=sim
# 200
# 전체 검색 데이터 수:  456162 검색할 페이지수:  4562
# https://openapi.naver.com/v1/search/blog.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=301&sort=sim
# 200
# 전체 검색 데이터 수:  456162 검색할 페이지수:  4562
# https://openapi.naver.com/v1/search/blog.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=401&sort=sim
# 200
# 전체 검색 데이터 수:  456162 검색할 페이지수:  4562
# https://openapi.naver.com/v1/search/blog.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=501&sort=sim
# 200
# 전체 검색 데이터 수:  456162 검색할 페이지수:  4562
# ...

# %% [markdown]
# ## 내가 한 것(수정하기)

# %%
payload=[]
i = 1
while i < 1000:
    i += 100
    if i == 1001:
        i -= 1
    payload.append({'query': book, 'display': 100, 'start':i , 'sort':'sim'})
payload
# Out:
# [{'query': '파이썬', 'display': 100, 'start': 101, 'sort': 'sim'},
#  {'query': '파이썬', 'display': 100, 'start': 201, 'sort': 'sim'},
#  {'query': '파이썬', 'display': 100, 'start': 301, 'sort': 'sim'},
#  {'query': '파이썬', 'display': 100, 'start': 401, 'sort': 'sim'},
#  {'query': '파이썬', 'display': 100, 'start': 501, 'sort': 'sim'},
#  {'query': '파이썬', 'display': 100, 'start': 601, 'sort': 'sim'},
#  {'query': '파이썬', 'display': 100, 'start': 701, 'sort': 'sim'},
#  {'query': '파이썬', 'display': 100, 'start': 801, 'sort': 'sim'},
#  {'query': '파이썬', 'display': 100, 'start': 901, 'sort': 'sim'},
#  {'query': '파이썬', 'display': 100, 'start': 1000, 'sort': 'sim'}]

# %%
import requests
url = "https://openapi.naver.com/v1/search/book.json"
book = input("책 제목을 입력하세요")
payload = {'query': book, 'display': 100, 'start':1000 , 'sort':'sim'}
headers = {"X-Naver-Client-Id":"YYIYgjstxPdUpH7WXuUE", "X-Naver-Client-Secret":"wqrbMV9nRh"}
r = requests.get(url, params=payload, headers=headers)
print(r.url)
print(r.status_code)
data = r.json()
print("전체 검색 데이터 수 :", data["total"], "검색할 페이지수:", (int(data["total"])//100)+1)
# Out:
# 책 제목을 입력하세요파이썬
# https://openapi.naver.com/v1/search/book.json?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC&display=100&start=1000&sort=sim
# 200
# 전체 검색 데이터 수 : 1113 검색할 페이지수: 12

# %%
result_df = json_unpack(data)
result_df
# Out:
#                                                 title  \
# 0   파이썬과 케라스를 이용한 딥러닝/강화학습 주식투자 (퀀트 투자 알고리즘 트레이딩을 ...
# 1   슬기로운 코딩 생활 with 파이썬 으랏차차 기초편 (즐겁게 시작하고 똑똑하게 끝내...
# 2   2024 내일은 빅데이터분석기사 실기 with 파이썬 (제6회부터 변경된 작업형 제...
# 3   2024 빅데이터분석기사 실기 한권완성: 파이썬(Python) (작업형 제3유형 완...
# 4   Step by Step CRM을 위한 파이썬 머신러닝 (빅 데이터 분석 자격증 머신...
# ..                                                ...
# 95  챗GPT와 업무자동화 (1분 만에 끝내는 엑셀, 구글 시트, 파워포인트, 파이썬 자...
# 96  프로그래밍 정석(개념을 잡아주는) (기초 연산부터 고급 문제해결 능력까지 파이썬을 ...
# 97  머신러닝 딥러닝을 이용한 A.I. 자율주행 RC카 프로젝트 with 파이썬+아두이노...
# 98         파이썬 딥러닝 파이토치(Python Deep Learning PyTorch)
# 99  Let’s Start Coding with Raptor & Python (랩터 & ...
#
#                                                  link  \
# 0   https://search.shopping.naver.com/book/catalog...
# 1   https://search.shopping.naver.com/book/catalog...
# 2   https://search.shopping.naver.com/book/catalog...
# 3   https://search.shopping.naver.com/book/catalog...
# ...

# %%
while True:
    if page <== tatal_page
    import requests
    url = "https://openapi.naver.com/v1/search/book.json"
    book = input("책 제목을 입력하세요")
    payload = {'query': book, 'display': 100, 'start':1000 , 'sort':'sim'}
    headers = {"X-Naver-Client-Id":"YYIYgjstxPdUpH7WXuUE", "X-Naver-Client-Secret":"wqrbMV9nRh"}
    r = requests.get(url, params=payload, headers=headers)
    print(r.url)
    print(r.status_code)
    data = r.json()
    print("전체 검색 데이터 수 :", data["total"], "검색할 페이지수:", (int(data["total"])//100)+1)
# Out:
#   Cell In[11], line 2
#     if page <== tatal_page
#               ^
# SyntaxError: invalid syntax

# %% [markdown]
# for 문

# %%
all_data = []

# %%
start = 101
for page in range(total_pages):
    import requests
    url = "https://openapi.naver.com/v1/search/book.json"
    book = input("책 제목을 입력하세요")
    payload = {'query': book, 'display': 100, 'start':start , 'sort':'sim'}
    headers = {"X-Naver-Client-Id":"YYIYgjstxPdUpH7WXuUE", "X-Naver-Client-Secret":"wqrbMV9nRh"}
    r = requests.get(url, params=payload, headers=headers)
    print(r.url)
    print(r.status_code)
    data = r.json()
    n_data = data["total"]
    total_pages = (int(data["total"])//100)+1
    print("전체 검색 데이터 수 :", data["total"], "검색할 페이지수:", (int(data["total"])//100)+1)
    result_df = json_unpack(data)
    all_data.append(result_df)
    if start == 1000:
        break
    elif start < 901:
        start += 100
    elif start == 901:
        start += 99
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 start = 101
# ----> 2 for page in range(total_pages):
#       3     import requests
#       4     url = "https://openapi.naver.com/v1/search/book.json"
#
# NameError: name 'total_pages' is not defined

# %%
payload=[]
i = 1
while i < 1000:
    i += 100
    if i == 1001:
        i -= 1
    payload.append({'query': book, 'display': 100, 'start':i , 'sort':'sim'})
payload

# %%
import requests
url = "https://openapi.naver.com/v1/search/book.json"
result2=[]
book = input("책 제목을 입력하세요")
i = 1
while i < 1000:
    i += 100
    if i == 1001:
        i -= 1
    payload = {'query': book, 'display': 100, 'start':i, 'sort':'sim'}
    headers = {"X-Naver-Client-Id":"YYIYgjstxPdUpH7WXuUE", "X-Naver-Client-Secret":"wqrbMV9nRh"}
    r = requests.get(url, params=payload, headers=headers)
    data = r.json()

    result2.append(data)

# %%
for i in result2:
    result2[i]['items']

# %% [markdown]
# # While문으로 데이터 모두 가져오기

# %%
all_data2 = []
start = 1
while True:
    import requests
    url = "https://openapi.naver.com/v1/search/book.json"
    book = input("책 제목을 입력하세요")
    payload = {'query': book, 'display': 100, 'start':1000 , 'sort':'sim'}
    headers = {"X-Naver-Client-Id":"YYIYgjstxPdUpH7WXuUE", "X-Naver-Client-Secret":"wqrbMV9nRh"}
    r = requests.get(url, params=payload, headers=headers)
    print(r.url)
    print(r.status_code)
    data = r.json()
    n_data = data["total"]
    total_pages = (int(data["total"])//100)+1
    print("전체 검색 데이터 수 :", data["total"], "검색할 페이지수:", (int(data["total"])//100)+1)
    result_df = json_unpack(data)
    all_data2.append(result_df)
    if start == 1000:
        break
    if start < 901:
        start +=100
    elif start == 901:
        start + 99
# Out:
# 책 제목을 입력하세요파이썬
# https://openapi.naver.com/v1/search/book.json?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC&display=100&start=1000&sort=sim
# 200
# 전체 검색 데이터 수 : 1113 검색할 페이지수: 12

# %% [markdown]
# # 뉴스, 블로그 책 한번에 검색해서 저장하기
