# %%
import requests
import time
import pandas as pd
from bs4 import BeautifulSoup as bs

# %%
url = "https://kind.krx.co.kr/corpgeneral/corpList.do"
payload = dict(method="searchCorpList", pageIndex=1, currentPageSize=100, orderMode=3, orderStat="D", searchType=13, fiscalYearEnd="all", location="all")

# %%
r = requests.post(url, data=payload)
print(r.status_code)
soup = bs(r.content, "lxml")
soup
# Out:
# 200
# <html><body><section class="scrarea type-00">
# <table class="list type-00 tmt30" summary="회사명, 업종, 주요제품, 상장일, 결산월, 대표자명, 홈페이지, 지역">
# <caption>목록</caption>
# <colgroup>
# <col width="*"/>
# <col width="15%"/>
# <col width="20%"/>
# <col width="11%"/>
# <col width="8%"/>
# <col width="10%"/>
# <col width="8%"/>
# <col width="12%"/>
# </colgroup>
# <thead>
# <tr class="first" id="title-contents">
# </tr>
# </thead>
# <tbody>
# <tr class="first">
# <td class="first" title="한국피아이엠(주)"><img alt="코스닥" class="vmiddle legend" src="/images/common/icn_t_ko.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('44890'); return false;" title="한국피아이엠"> 한국피아이엠</a> </td>
# <td class="textOverflow" title="자동차 신품 부품 제조업">자동차 신품 부품 제조업</td>
# <td class="textOverflow" title="내연기관 부품(터보차저, DCT변속기), IT 부품(스마트워치/스마트링), 자율주행 부품(카메라 모듈 케이스)">내연기관 부품(터보차저, DCT변속기), IT 부품(스마트워치/스마트링), 자율주행 부품(카메라 모듈 케이스)</td>
# <td class="txc">2025-04-04</td>
# <td class="txc">12월</td>
# ...

# %%
sto = []
for s_sto in soup.select("img.vmiddle.legend"):
    sto.append(s_sto["alt"])
sto
# Out:
# ['코스닥',
#  '코스닥',
#  '코스닥',
#  '코스닥',
#  '코스닥',
#  '코스닥',
#  '코스닥',
#  '코스닥',
#  '유가증권',
#  '유가증권',
#  '코스닥',
#  '코스닥',
#  '코스닥',
#  '코스닥',
#  '코스닥',
#  '코스닥',
#  '코스닥',
#  '코스닥',
#  '코스닥',
#  '코스닥',
#  '코스닥',
#  '유가증권',
#  '코스닥',
#  '코스닥',
#  '코스닥',
#  '코스닥',
#  '코스닥',
#  '코스닥',
#  '코스닥',
#  '코스닥',
#  '코스닥',
#  '코넥스',
#  '코스닥',
#  '코스닥',
#  '코스닥',
#  '유가증권',
#  'KRX300',
#  '코스닥',
#  '코넥스',
#  '코넥스',
#  '코스닥',
#  '코스닥',
#  '코스닥',
#  '코스닥',
#  '코스닥',
#  '코스닥',
#  '유가증권',
#  '코스닥',
#  '코넥스',
#  '코스닥',
#  '코스닥',
#  '유가증권',
#  '코스닥',
#  '코스닥',
#  '코스닥',
#  '코스닥',
#  '코스닥',
#  '코스닥',
#  '코스닥',
#  '코스닥',
#  '코스닥',
#  '코스닥',
#  '코스닥',
#  '코스닥',
#  '코스닥',
#  '코스닥',
#  '코스닥',
#  '코스닥',
#  '유가증권',
#  '코스닥',
#  '코스닥',
#  '코스닥',
#  '코스닥',
#  '코스닥',
#  '코넥스',
#  '코스닥',
#  '코스닥',
#  '코스닥',
#  '코스닥',
#  '코스닥',
#  '코스닥',
#  '코스닥',
#  '코스닥',
#  '코스닥',
#  '코스닥',
#  '코스닥',
#  '유가증권',
#  'KOSPI200',
#  'KRX300',
#  '코스닥',
#  '코스닥',
#  '코스닥',
#  '코스닥',
#  '코스닥',
#  '코스닥',
#  '코스닥',
#  '코스닥',
#  '코스닥',
# ...

# %%
title = []
for s_title in soup.select("a#companysum"):
    title.append(s_title.text.strip())
title
# Out:
# ['한국피아이엠',
#  '에이유브랜즈',
#  '우양에이치씨',
#  '더즌',
#  '심플랫폼',
#  '티엑스알로보틱스',
#  '한텍',
#  '한화플러스제5호스팩',
#  '씨케이솔루션',
#  '서울보증보험',
#  '에스엠씨지',
#  '엠디바이스',
#  '대진첨단소재',
#  '에르코스',
#  '엘케이켐',
#  '위너스',
#  '모티브링크',
#  '동국생명과학',
#  '오름테라퓨틱',
#  '동방메디컬',
#  '아이에스티이',
#  'LG씨엔에스',
#  '아이지넷',
#  '피아이이',
#  '삼양엔씨켐',
#  '데이원컴퍼니',
#  '아스테라시스',
#  '와이즈넛',
#  '미트박스',
#  '유안타제17호스팩',
#  '블랙야크아이앤씨',
#  '오션스바이오',
#  '엠에프씨',
#  '파인메딕스',
#  '쓰리에이로직스',
#  'GS피앤엘',
#  '신한제14호스팩',
#  '유비씨',
#  '창대정밀',
#  '듀켐바이오',
#  '키움제10호스팩',
#  '에스지헬스케어',
#  '온코닉테라퓨틱스',
#  '온코크로스',
#  '벡트',
#  '엠앤씨솔루션',
#  '셀로맥스사이언스',
#  '에이엠시지',
#  'KB제31호스팩',
#  '키움제11호스팩',
#  'KB발해인프라',
#  '디비금융제13호스팩',
#  '교보17호스팩',
#  '대신밸런스제19호스팩',
#  '위츠',
#  '유디엠텍',
#  'RF시스템즈',
#  '사이냅소프트',
#  '하나34호스팩',
#  '에스켐',
#  '엠오티',
#  '신한제15호스팩',
#  '쓰리빌리언',
#  '닷밀',
#  '노머스',
#  '에어레인',
#  '토모큐브',
#  '더본코리아',
#  '에이치이엠파마',
#  '에이럭스',
#  '탑런토탈솔루션',
#  '성우',
#  '유진스팩11호',
#  '타조엔터테인먼트',
#  '클로봇',
#  '에이치엔에스하이텍',
#  '웨이비스',
#  '씨메스',
#  '한켐',
#  '루미르',
# ...

# %%
genre = []
for s_genre in soup.select("td.textOverflow"):
    genre.append(s_genre.text.strip())
genre
# Out:
# ['자동차 신품 부품 제조업',
#  '내연기관 부품(터보차저, DCT변속기), IT 부품(스마트워치/스마트링), 자율주행 부품(카메라 모듈 케이스)',
#  '섬유, 의복, 신발 및 가죽제품 소매업',
#  '레인부츠, 스니커즈, 겨울화, 패션잡화 등',
#  '구조용 금속제품, 탱크 및 증기발생기 제조업',
#  '화공 플랜트, 에너지 플랜트',
#  '전기 통신업',
#  '디지털뱅킹 솔루션(B2B 금융 서비스)',
#  '소프트웨어 개발 및 공급업',
#  'NUBISON AIoT(산업용 데이터 수집과 산업용 AI서비스 운영)',
#  '일반 목적용 기계 제조업',
#  '물류자동화, 로봇자동화, AMR/AGV',
#  '일반 목적용 기계 제조업',
#  '열교환기 등 화공기기, 저장용 탱크',
#  '금융 지원 서비스업',
#  '-',
#  '건축기술, 엔지니어링 및 관련 기술 서비스업',
#  '드라이룸/클린룸 등 건물용 기계, 장비 설치 공사업',
#  '보험업',
#  '보증보험, 신용보험 등',
#  '유리 및 유리제품 제조업',
#  '화장품 유리용기',
#  '전자부품 제조업',
#  '반도체기억장치',
#  '플라스틱제품 제조업',
#  '이차전지 공정용 대전방지트레이, 대전방지코팅액, 이차전지용 PET이형필름',
#  '도시락 및 식사용 조리식품 제조업',
#  '영유아식, 고령친화식품, 식물기반 대체식품',
#  '기타 화학제품 제조업',
#  '반도체 소재(CP, PCP, DIS) 등',
#  '기타 전기장비 제조업',
#  '배선기구(스위치, 콘센트, 멀티탭), 전기차 충전기(급속, 완속)',
#  '전자부품 제조업',
#  'EV용 Main Transformer, EV용 Line Filter',
#  '의약품 제조업',
#  '조영제 완제 및 원료, 의료기기 유통',
#  '기초 의약물질 제조업',
#  '항체약물접합체(ADC) 단백질 분해제(TPD) 연구 개발',
#  '의료용 기기 제조업',
#  '필러, 한방침',
# ...

# %%
number = []
for s_number in soup.select("a#companysum"):
    number.append(s_number["onclick"][21:26])
number
# Out:
# ['44890',
#  '48107',
#  '10197',
#  '46286',
#  '44453',
#  '48481',
#  '09807',
#  '49839',
#  '48037',
#  '03121',
#  '46087',
#  '22659',
#  '39397',
#  '43557',
#  '48950',
#  '47996',
#  '46348',
#  '30381',
#  '47583',
#  '24055',
#  '21271',
#  '06440',
#  '46298',
#  '45245',
#  '48263',
#  '37316',
#  '45095',
#  '09625',
#  '47546',
#  '49379',
#  '47856',
#  '33219',
#  '43298',
#  '38757',
#  '17790',
#  '49979',
#  '48736',
#  '49581',
#  '36803',
#  '17675',
#  '48772',
#  '39812',
#  '47606',
#  '38215',
#  '45760',
#  '48487',
#  '47182',
#  '49590',
#  '49222',
#  '48948',
#  '41564',
#  '48973',
#  '48921',
#  '48269',
#  '45910',
#  '38968',
#  '47461',
#  '46641',
#  '48413',
#  '47566',
#  '41339',
#  '48783',
#  '39480',
#  '46458',
#  '47398',
#  '16328',
#  '47596',
#  '47556',
#  '37627',
#  '47558',
#  '33668',
#  '45865',
#  '48806',
#  '47671',
#  '46610',
#  '04499',
#  '28993',
#  '47540',
#  '45737',
#  '47417',
#  '20964',
#  '46548',
#  '30843',
# ...

# %%
product = []
for s_product in soup.select("td:nth-child(3)"):
    product.append(s_product.text)
product
# Out:
# ['내연기관 부품(터보차저, DCT변속기), IT 부품(스마트워치/스마트링), 자율주행 부품(카메라 모듈 케이스)',
#  '레인부츠, 스니커즈, 겨울화, 패션잡화 등',
#  '화공 플랜트, 에너지 플랜트',
#  '디지털뱅킹 솔루션(B2B 금융 서비스)',
#  'NUBISON AIoT(산업용 데이터 수집과 산업용 AI서비스 운영)',
#  '물류자동화, 로봇자동화, AMR/AGV',
#  '열교환기 등 화공기기, 저장용 탱크',
#  '-',
#  '드라이룸/클린룸 등 건물용 기계, 장비 설치 공사업',
#  '보증보험, 신용보험 등',
#  '화장품 유리용기',
#  '반도체기억장치',
#  '이차전지 공정용 대전방지트레이, 대전방지코팅액, 이차전지용 PET이형필름',
#  '영유아식, 고령친화식품, 식물기반 대체식품',
#  '반도체 소재(CP, PCP, DIS) 등',
#  '배선기구(스위치, 콘센트, 멀티탭), 전기차 충전기(급속, 완속)',
#  'EV용 Main Transformer, EV용 Line Filter',
#  '조영제 완제 및 원료, 의료기기 유통',
#  '항체약물접합체(ADC) 단백질 분해제(TPD) 연구 개발',
#  '필러, 한방침',
#  '반도체 제조용 장비',
#  '컨설팅, 시스템 구축/운영, 토탈 아웃소싱 및 AI, 클라우드·스마트팩토리 등 IT신기술 기반의 DX사업',
#  '보험 서비스 어플리케이션, 기업용 보험 솔루션',
#  'AI 비전 솔루션 및 스마트팩토리 솔루션',
#  '반도체 포토레지스트용 기초화합물(KrF PR용 소재, ArF PR용 소재, Wet Chemical)',
#  '성인대상 교육서비스',
#  '피부 미용의료기기 제조, 판매',
#  '검색엔진, 챗봇, 클라우드서비스',
#  '축산물 도소매 판매 및 중개',
#  '금융 지원 서비스업',
#  '산업용 안전화, 안전복 및 안전용품',
#  '전자약',
#  '원료의약품(API) 및 핵심소재',
# ...

# %%
date = []
for s_date in soup.select("td:nth-child(4)"):
    date.append(s_date.text)
date
# Out:
# ['2025-04-04',
#  '2025-04-03',
#  '2025-03-28',
#  '2025-03-24',
#  '2025-03-21',
#  '2025-03-20',
#  '2025-03-20',
#  '2025-03-20',
#  '2025-03-17',
#  '2025-03-14',
#  '2025-03-07',
#  '2025-03-07',
#  '2025-03-06',
#  '2025-02-28',
#  '2025-02-25',
#  '2025-02-24',
#  '2025-02-20',
#  '2025-02-17',
#  '2025-02-14',
#  '2025-02-13',
#  '2025-02-12',
#  '2025-02-05',
#  '2025-02-04',
#  '2025-02-04',
#  '2025-02-03',
#  '2025-01-24',
#  '2025-01-24',
#  '2025-01-24',
#  '2025-01-23',
#  '2025-01-23',
#  '2025-01-21',
#  '2025-01-14',
#  '2024-12-26',
#  '2024-12-26',
#  '2024-12-24',
#  '2024-12-23',
#  '2024-12-23',
#  '2024-12-23',
#  '2024-12-23',
#  '2024-12-20',
#  '2024-12-20',
#  '2024-12-19',
#  '2024-12-19',
#  '2024-12-18',
#  '2024-12-16',
#  '2024-12-16',
#  '2024-12-13',
#  '2024-12-13',
#  '2024-12-12',
#  '2024-12-11',
#  '2024-11-29',
#  '2024-11-28',
#  '2024-11-21',
#  '2024-11-20',
#  '2024-11-20',
#  '2024-11-20',
#  '2024-11-19',
#  '2024-11-19',
# ...

# %%
month = []
for s_month in soup.select("td:nth-child(5)"):
    month.append(s_month.text)
month
# Out:
# ['12월',
#  '12월',
#  '12월',
#  '12월',
#  '12월',
#  '12월',
#  '12월',
#  '12월',
#  '12월',
#  '12월',
#  '12월',
#  '12월',
#  '12월',
#  '12월',
#  '12월',
#  '12월',
#  '12월',
#  '12월',
#  '12월',
#  '12월',
#  '12월',
#  '12월',
#  '12월',
#  '12월',
#  '12월',
#  '12월',
#  '12월',
#  '12월',
#  '12월',
#  '12월',
#  '12월',
#  '12월',
#  '12월',
#  '12월',
#  '12월',
#  '12월',
#  '12월',
#  '12월',
#  '12월',
#  '12월',
#  '12월',
#  '12월',
#  '12월',
#  '12월',
#  '12월',
#  '12월',
#  '12월',
#  '12월',
#  '12월',
#  '12월',
#  '12월',
#  '12월',
#  '12월',
#  '12월',
#  '12월',
#  '12월',
#  '12월',
#  '12월',
#  '12월',
#  '12월',
#  '12월',
#  '12월',
#  '12월',
#  '12월',
#  '12월',
#  '12월',
#  '12월',
#  '12월',
#  '12월',
#  '12월',
#  '12월',
#  '12월',
#  '12월',
#  '12월',
#  '12월',
#  '12월',
#  '12월',
#  '12월',
#  '12월',
#  '12월',
#  '12월',
#  '12월',
#  '12월',
#  '12월',
#  '12월',
#  '12월',
#  '12월',
#  '12월',
#  '12월',
#  '12월',
#  '12월',
#  '12월',
#  '12월',
#  '12월',
#  '12월',
#  '12월',
#  '12월',
#  '12월',
#  '12월',
#  '12월']

# %%
ceo = []
for s_ceo in soup.select("td:nth-child(6)"):
    ceo.append(s_ceo.text)
ceo
# Out:
# ['송준호',
#  '김지훈',
#  '김진태',
#  '조철한',
#  '임대근..',
#  '엄인섭',
#  '김강식',
#  '김광후',
#  '김유곤..',
#  '이명순',
#  '최승호',
#  '조호경',
#  '유성준..',
#  '김슬기',
#  '이창엽',
#  '김창성',
#  '김기한',
#  '박재원',
#  '이승주',
#  '김근식',
#  '조창현',
#  '현신균',
#  '김창균..',
#  '최정일..',
#  '정회식',
#  '이강민',
#  '서은택',
#  '강용성',
#  '김기봉',
#  '윤원도',
#  '김태효',
#  '이현웅',
#  '황성관..',
#  '전성우..',
#  '박광범..',
#  '김원식',
#  '정우주',
#  '조규종',
#  '박제현..',
#  '김상우',
#  '김대식',
#  '김정수',
#  '김존',
#  '김이랑..',
#  '유창수',
#  '김병근',
#  '서정민',
#  '서용성',
#  '김형철',
#  '조선희',
#  '법인이..',
#  '양준석',
#  '장정훈',
#  '임병완',
#  '김응태',
#  '왕지남',
#  '한기우',
#  '전경헌',
#  '송하용',
#  '염호영',
#  '마점래',
#  '연오흠',
#  '금창원',
#  '정해운',
#  '김영준',
#  '하성용',
#  '박용근',
#  '백종원..',
#  '지요셉',
#  '이치헌',
#  '각 자..',
#  '박종헌',
#  '박홍식',
#  '이성호',
#  '각자 ..',
#  '김정희',
#  '한민석',
#  '이성호',
#  '이상조',
#  '남명용',
#  '박순일',
#  '최정규',
#  '김권',
#  '배성관',
#  '최영섭',
#  '안순홍',
#  '박홍진',
#  '박기태',
#  '송우영',
#  '길기재',
#  '허주환..',
#  '장종욱',
#  '정성진',
#  '문병식',
#  '김철준',
#  '이돈행',
#  '이재영',
# ...

# %%
h_url = []
for s_h_url in soup.select("a.btn.ico.homepage"):
    h_url.append(s_h_url["href"])
h_url
# Out:
# ['http://www.pimkorea.com',
#  'http://aubrandz.irpage.co.kr',
#  'http://www.wooyang.co.kr',
#  'http://www.dozn.co.kr/',
#  'http://simplatform.com/',
#  'http://www.txr.kr',
#  'http://hantechltd.com',
#  'http://www.cksolution.co.kr/',
#  'http://www.sgic.co.kr',
#  'http://www.somangglass.co.kr',
#  'http://daejin2019.com',
#  'http://www.ercohs.com',
#  'http://lkchem.co.kr',
#  'http://www.wns21.co.kr/',
#  'http://evpart.co.kr',
#  'http://dkls.co.kr',
#  'http://www.dongbangmedical.co.kr/',
#  'http://iste.co.kr/',
#  'http://www.lgcns.com',
#  'http://piegroup.co.kr',
#  'http://www.samyangncchem.com',
#  'http://day1company.co.kr/',
#  'http://asterasys.com',
#  'http://www.wisenut.com/',
#  'http://www.meatbox.co.kr',
#  'http://www.blackyakinc.com',
#  'http://www.mfcglobal.co.kr',
#  'http://www.3alogics.com/',
#  'http://www.gspnl.com',
#  'http://uvc.co.kr',
#  'http://www.i-changdae.com/',
#  'http://www.duchembio.com',
#  'http://sghealthcare.com/',
# ...

# %%
region = []
for s_region in soup.select("td:nth-child(8)"):
    region.append(s_region.text)
type(region)
# Out:
# list

# %%
for page in range(1, 29):
    url = "https://kind.krx.co.kr/corpgeneral/corpList.do"
    payload = dict(method="searchCorpList", pageIndex=page, currentPageSize=100, orderMode=3, orderStat="D", searchType=13, fiscalYearEnd="all", location="all")
    r = requests.post(url, data=payload)
    print(r.status_code)
    soup = bs(r.content, "lxml")
    sto = []
    for s_sto in soup.select("img.vmiddle.legend"):
        sto.append(s_sto["alt"])
    title = []
    for s_title in soup.select("a#companysum"):
        title.append(s_title.text.strip())
    genre = []
    for s_genre in soup.select("td.textOverflow"):
        genre.append(s_genre.text.strip())
    number = []
    for s_number in soup.select("a#companysum"):
        number.append(s_number["onclick"][21:26])
    product = []
    for s_product in soup.select("td:nth-child(3)"):
        product.append(s_product.text)
    date = []
    for s_date in soup.select("td:nth-child(4)"):
        date.append(s_date.text)
    month = []
    for s_month in soup.select("td:nth-child(5)"):
        month.append(s_month.text)
    ceo = []
    for s_ceo in soup.select("td:nth-child(6)"):
        ceo.append(s_ceo.text)
    h_url = []
    for s_h_url in soup.select("a.btn.ico.homepage"):
        h_url.append(s_h_url["href"])
    region = []
    for s_region in soup.select("td:nth-child(8)"):
        region.append(s_region.text)
        
    r_st.append(sto)
    r_ti.append(title)
    r_ge.append(genre)
    r_nu.append(number)
    r_pr.append(product)
    r_dt.append(date)
    r_mo.append(month)
    r_ce.append(ceo)
    r_ur.append(h_url)
    r_re.append(region)
# Out:
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200

# %%
r_st = []
r_ti = []
r_ge = []
r_nu = []
r_pr = []
r_dt = []
r_mo = []
r_ce = []
r_ur = []
r_re = []

# %%
result = dict(주식종목=r_st, 회사명=r_ti, 종목코드=r_nu, 업종=r_ge, 주요제품=r_pr, 상장일=r_dt, 결산월=r_mo, 대표자명=r_ce, 홈페이지=r_ur, 지역=r_re)

# %%
df = pd.DataFrame(result)
df
# Out:
#                                                  주식종목  \
# 0   [코스닥, 코스닥, 코스닥, 코스닥, 코스닥, 코스닥, 코스닥, 코스닥, 유가증권,...
# 1   [코스닥, 코스닥, 코스닥, 유가증권, 유가증권, 코스닥, 코스닥, 코스닥, 코스닥...
# 2   [유가증권, KOSPI200, KRX300, 코스닥, 코넥스, 코스닥, 코스닥, 코...
# 3   [코스닥, 유가증권, KRX300, 코넥스, 유가증권, 유가증권, 코스닥, 코스닥,...
# 4   [코스닥, 코스닥, 유가증권, 코스닥, 코스닥, KOSDAQ150, KRX300, ...
# 5   [코스닥, 유가증권, KOSPI200, KRX300, 코스닥, KOSDAQ150, ...
# 6   [코스닥, 코스닥, 코스닥, 코스닥, 코스닥, 관리종목, 투자주의환기종목, 코스닥,...
# 7   [유가증권, KOSPI200, KRX300, 코스닥, 유가증권, KRX300, 유가...
# 8   [코스닥, 코스닥, 코스닥, V100, KOSDAQ150, 코스닥, 코스닥, 코스닥...
# 9   [코스닥, KOSDAQ150, 코스닥, KOSDAQ150, 코스닥, 코스닥, 관리종...
# 10  [유가증권, 코스닥, 유가증권, KRX300, 유가증권, 코스닥, 코스닥, 코스닥,...
# 11  [코넥스, 코스닥, 코스닥, 관리종목, 코스닥, 유가증권, V100, KOSPI20...
# 12  [코스닥, 코스닥, 유가증권, KOSPI200, KRX300, 코스닥, 코스닥, 코...
# 13  [코스닥, 유가증권, 유가증권, KOSPI200, KRX300, 유가증권, KOSP...
# 14  [코스닥, 유가증권, 코스닥, 코스닥, 코스닥, 코스닥, 코스닥, 코스닥, 코스닥,...
# 15  [코스닥, 코스닥, 코스닥, 코스닥, 코스닥, 유가증권, V100, KOSPI200...
# ...

# %% [markdown]
# # 찾을 자료를 1개씩 찾아보기

# %%
url = "https://kind.krx.co.kr/corpgeneral/corpList.do"
payload = dict(method="searchCorpList", pageIndex=1, currentPageSize=100, orderMode=3, orderStat="D", searchType=13, fiscalYearEnd="all", location="all")
r = requests.post(url, data=payload)
print(r.status_code)
soup = bs(r.content, "lxml")
# Out:
# 200

# %%
soup.select("tbody > tr")[0].select_one("td:nth-child(1)")
# Out:
# <td class="first" title="한국피아이엠(주)"><img alt="코스닥" class="vmiddle legend" src="/images/common/icn_t_ko.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('44890'); return false;" title="한국피아이엠"> 한국피아이엠</a> </td>

# %%
# 주식종목
soup.select("tbody > tr")[0].select_one("td:nth-child(1) > img")["alt"]

# %%
#회사이름
soup.select("tbody > tr")[0].select_one("td:nth-child(1) > a")["title"]
# Out:
# '한국피아이엠'

# %%
#종목코드
soup.select("tbody > tr")[0].select_one("td:nth-child(1) > a")["onclick"][21:26]
# Out:
# '44890'

# %%
#업종
soup.select("tbody > tr")[0].select_one("td:nth-child(2)").text
# Out:
# '자동차 신품 부품 제조업'

# %%
#주요제품
soup.select("tbody > tr")[0].select_one("td:nth-child(3)").text
# Out:
# '내연기관 부품(터보차저, DCT변속기), IT 부품(스마트워치/스마트링), 자율주행 부품(카메라 모듈 케이스)'

# %%
#상장일
soup.select("tbody > tr")[0].select_one("td:nth-child(4)").text
# Out:
# '2025-04-04'

# %%
#결산월
soup.select("tbody > tr")[0].select_one("td:nth-child(5)").text
# Out:
# '12월'

# %%
#대표자명
soup.select("tbody > tr")[0].select_one("td:nth-child(6)").text
# Out:
# '송준호'

# %%
#홈페이지(url)
soup.select("tbody > tr")[0].select_one("td:nth-child(7) > a")["href"]
# Out:
# 'http://www.pimkorea.com'

# %%
#지역
soup.select("tbody > tr")[0].select_one("td:nth-child(8)").text
# Out:
# '대구광역시'

# %%
#전체 페이지
total_page = int(soup.select_one(".info.type-00 > em").text.replace(",",""))

# %%
# 컬럼명
columns = soup.select_one("table")["summary"].split(", ")
columns.insert(0, "주식종목")

# %%
columns.insert(2, "종목코드")
columns
# Out:
# ['주식종목',
#  '회사명',
#  '종목코드',
#  '종목코드',
#  '업종',
#  '주요제품',
#  '상장일',
#  '결산월',
#  '대표자명',
#  '홈페이지',
#  '지역']

# %% [markdown]
# # 코드 합쳐서 1페이지 정보 모두 추출하기

# %%
url = "https://kind.krx.co.kr/corpgeneral/corpList.do"
payload = dict(method="searchCorpList", pageIndex=1, currentPageSize=100, orderMode=3, orderStat="D", searchType=13, fiscalYearEnd="all", location="all")
r = requests.post(url, data=payload)
print(r.status_code)
soup = bs(r.content, "lxml")
company_infos = []
for tr in soup.select("tbody > tr"):
    # 주식종목
    stock_type = tr.select_one("td:nth-child(1) > img")["alt"]
    #회사이름
    company_name = tr.select_one("td:nth-child(1) > a")["title"]
    #종목코드
    stock_code = tr.select_one("td:nth-child(1) > a")["onclick"][21:26]
    #업종
    business_type = tr.select_one("td:nth-child(2)").text
    #주요제품
    product = tr.select_one("td:nth-child(3)").text
    #상장일
    resi_date = tr.select_one("td:nth-child(4)").text
    #결산월
    settlement = tr.select_one("td:nth-child(5)").text
    #대표자명
    ceo = tr.select_one("td:nth-child(6)").text
    #홈페이지(url)
    homepage = tr.select_one("td:nth-child(7) > a")["href"]
    #지역
    region = tr.select_one("td:nth-child(8)").text
    
    company_infos.append(stock_type, company_name, stock_code, business_type, product, resi_date, settlement, ceo, homepage, region)
    
company_infos
# Out:
# 200
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[144], line 29
#      26     #지역
#      27     region = tr.select_one("td:nth-child(8)").text
# ---> 29     company_infos.append(stock_type, company_name, stock_code, business_type, product, resi_date, settlement, ceo, homepage, region)
#      31 company_infos
#
# TypeError: list.append() takes exactly one argument (10 given)

# %% [markdown]
# # 데이터를 수집한 날짜를 포함해서 파일명을 만들고 저장하기

# %%
from datetime import datetime

# %%
today = datetime.now()
print(f"{today.year}_{today.month}_{today.day}")
# Out:
# 2025_4_4

# %% [markdown]
# # 수집한 자료를 데이터베이스에 저장하기

# %%
from sqlalchemy import create_engine, text
import pymysql
pymysql.install_as_MySQLdb()

# %% [markdown]
# * sqlalchemy의 ceate_engine을 이용해서 mysql 서버에 접속
# engine = create_engine("mysql+pymysql://userid:password@ip주소:port/데이터베이스 이름")

# %%
# sqlalchemy의 ceate_engine을 이용해서 mysql 서버에 접속
# localhost = 127.0.0.1
engine = create_engine("mysql+pymysql://root:1234@localhost:3306/stock_info")
# engine.connect create_engine에 있는 정보로 DB 접속
conn = engine.connect()

# %%
# 데이터프레임을 DB에 저장하기
# 데이터프레임명.to_sql("테이블명")
df.to_sql(f"stock_company_info_{today}", con=conn, if_exists='replace', index=False)
conn.close()

# %% [markdown]
# # 판다스의 read_html를 이용해서 table 자료 한번에 가져오기

# %%
soup.select_one("table")
# Out:
# <table class="list type-00 tmt30" summary="회사명, 업종, 주요제품, 상장일, 결산월, 대표자명, 홈페이지, 지역">
# <caption>목록</caption>
# <colgroup>
# <col width="*"/>
# <col width="15%"/>
# <col width="20%"/>
# <col width="11%"/>
# <col width="8%"/>
# <col width="10%"/>
# <col width="8%"/>
# <col width="12%"/>
# </colgroup>
# <thead>
# <tr class="first" id="title-contents">
# </tr>
# </thead>
# <tbody>
# <tr class="first">
# <td class="first" title="한국피아이엠(주)"><img alt="코스닥" class="vmiddle legend" src="/images/common/icn_t_ko.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('44890'); return false;" title="한국피아이엠"> 한국피아이엠</a> </td>
# <td class="textOverflow" title="자동차 신품 부품 제조업">자동차 신품 부품 제조업</td>
# <td class="textOverflow" title="내연기관 부품(터보차저, DCT변속기), IT 부품(스마트워치/스마트링), 자율주행 부품(카메라 모듈 케이스)">내연기관 부품(터보차저, DCT변속기), IT 부품(스마트워치/스마트링), 자율주행 부품(카메라 모듈 케이스)</td>
# <td class="txc">2025-04-04</td>
# <td class="txc">12월</td>
# <td class="txc" title="송준호">송준호</td>
# <td class="txc">
# ...

# %%
pd.read_html(soup.select_one("table"))
