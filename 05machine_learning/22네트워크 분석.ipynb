# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
import koreanize_matplotlib

# %%
import matplotlib.font_manager as fm
import platform

font_path = "C:/Windows/Fonts/malgun.ttf" # 맑은 고딕 폰트 경로
font_prop = fm.FontProperties(fname=font_path)

# %%
df_sample = pd.read_csv("./data/network_data.csv")
df_sample.head()
# Out:
#     고객ID   고객이름  동반인ID                      주문메뉴
# 0  C0116  고객116    NaN             ['쫄면', '칼국수']
# 1  C0169  고객169    NaN  ['순두부찌개', '된장찌개', '불고기']
# 2  C0086   고객86  C0153                    ['쫄면']
# 3  C0104  고객104  C0163  ['순두부찌개', '된장찌개', '비빔밥']
# 4  C0126  고객126    NaN           ['비빔밥', '김치찌개']

# %%
# 고객id : 고객 이름 매칭 딕셔너리 만들기
customer_dict = dict(zip(df_sample["고객ID"], df_sample["고객이름"]))
customer_dict
# Out:
# {'C0116': '고객116',
#  'C0169': '고객169',
#  'C0086': '고객86',
#  'C0104': '고객104',
#  'C0126': '고객126',
#  'C0184': '고객184',
#  'C0181': '고객181',
#  'C0154': '고객154',
#  'C0081': '고객81',
#  'C0199': '고객199',
#  'C0149': '고객149',
#  'C0058': '고객58',
#  'C0042': '고객42',
#  'C0187': '고객187',
#  'C0176': '고객176',
#  'C0107': '고객107',
#  'C0177': '고객177',
#  'C0027': '고객27',
#  'C0144': '고객144',
#  'C0072': '고객72',
#  'C0123': '고객123',
#  'C0132': '고객132',
#  'C0005': '고객5',
#  'C0140': '고객140',
#  'C0048': '고객48',
#  'C0049': '고객49',
#  'C0114': '고객114',
#  'C0138': '고객138',
#  'C0045': '고객45',
#  'C0031': '고객31',
#  'C0078': '고객78',
#  'C0164': '고객164',
#  'C0047': '고객47',
#  'C0028': '고객28',
#  'C0089': '고객89',
#  'C0119': '고객119',
#  'C0170': '고객170',
#  'C0150': '고객150',
#  'C0004': '고객4',
#  'C0093': '고객93',
#  'C0069': '고객69',
#  'C0180': '고객180',
#  'C0143': '고객143',
#  'C0021': '고객21',
#  'C0030': '고객30',
#  'C0200': '고객200',
#  'C0139': '고객139',
#  'C0092': '고객92',
#  'C0159': '고객159',
#  'C0088': '고객88',
#  'C0195': '고객195',
#  'C0076': '고객76',
#  'C0053': '고객53',
#  'C0033': '고객33',
#  'C0098': '고객98',
#  'C0172': '고객172',
#  'C0173': '고객173',
#  'C0036': '고객36',
#  'C0105': '고객105',
#  'C0121': '고객121',
#  'C0130': '고객130',
#  'C0009': '고객9',
#  'C0145': '고객145',
#  'C0158': '고객158',
#  'C0106': '고객106',
#  'C0080': '고객80',
#  'C0020': '고객20',
#  'C0017': '고객17',
#  'C0051': '고객51',
#  'C0083': '고객83',
#  'C0067': '고객67',
#  'C0046': '고객46',
#  'C0183': '고객183',
#  'C0039': '고객39',
#  'C0111': '고객111',
#  'C0043': '고객43',
#  'C0013': '고객13',
#  'C0109': '고객109',
#  'C0091': '고객91',
#  'C0074': '고객74',
#  'C0153': '고객153',
#  'C0168': '고객168',
#  'C0196': '고객196',
#  'C0035': '고객35',
#  'C0175': '고객175',
#  'C0071': '고객71',
#  'C0133': '고객133',
#  'C0115': '고객115',
#  'C0061': '고객61',
#  'C0103': '고객103',
#  'C0064': '고객64',
#  'C0129': '고객129',
#  'C0022': '고객22',
#  'C0077': '고객77',
#  'C0193': '고객193',
#  'C0090': '고객90',
#  'C0073': '고객73',
#  'C0120': '고객120',
#  'C0161': '고객161',
#  'C0110': '고객110',
#  'C0188': '고객188',
#  'C0062': '고객62',
#  'C0054': '고객54',
#  'C0148': '고객148',
#  'C0186': '고객186',
#  'C0057': '고객57',
#  'C0055': '고객55',
#  'C0147': '고객147',
#  'C0131': '고객131',
#  'C0128': '고객128',
#  'C0198': '고객198',
#  'C0100': '고객100',
#  'C0023': '고객23',
#  'C0185': '고객185',
#  'C0029': '고객29',
#  'C0041': '고객41',
#  'C0182': '고객182',
#  'C0034': '고객34',
#  'C0007': '고객7',
#  'C0094': '고객94',
#  'C0018': '고객18',
#  'C0087': '고객87',
#  'C0024': '고객24',
#  'C0059': '고객59',
#  'C0095': '고객95',
#  'C0066': '고객66',
#  'C0016': '고객16',
#  'C0084': '고객84',
#  'C0135': '고객135',
#  'C0025': '고객25',
#  'C0019': '고객19',
#  'C0082': '고객82',
#  'C0127': '고객127',
#  'C0003': '고객3',
#  'C0136': '고객136',
#  'C0050': '고객50',
#  'C0040': '고객40',
#  'C0141': '고객141',
#  'C0085': '고객85',
#  'C0001': '고객1',
#  'C0167': '고객167',
#  'C0122': '고객122',
#  'C0171': '고객171',
#  'C0124': '고객124',
#  'C0151': '고객151',
#  'C0160': '고객160',
#  'C0096': '고객96',
#  'C0117': '고객117',
#  'C0015': '고객15',
#  'C0113': '고객113',
#  'C0044': '고객44',
#  'C0118': '고객118',
#  'C0097': '고객97',
#  'C0155': '고객155',
#  'C0134': '고객134',
#  'C0070': '고객70',
#  'C0002': '고객2',
#  'C0079': '고객79',
#  'C0178': '고객178',
#  'C0063': '고객63',
#  'C0190': '고객190',
#  'C0152': '고객152',
#  'C0191': '고객191',
#  'C0156': '고객156',
#  'C0010': '고객10',
#  'C0112': '고객112',
#  'C0146': '고객146',
#  'C0075': '고객75',
#  'C0197': '고객197',
#  'C0099': '고객99',
#  'C0065': '고객65',
#  'C0032': '고객32',
#  'C0108': '고객108',
#  'C0012': '고객12',
#  'C0008': '고객8',
#  'C0166': '고객166',
#  'C0060': '고객60',
#  'C0068': '고객68',
#  'C0014': '고객14',
#  'C0038': '고객38',
#  'C0101': '고객101',
#  'C0026': '고객26',
#  'C0179': '고객179',
#  'C0194': '고객194',
#  'C0137': '고객137',
#  'C0163': '고객163',
#  'C0142': '고객142',
#  'C0052': '고객52',
#  'C0192': '고객192',
#  'C0102': '고객102',
#  'C0056': '고객56',
#  'C0189': '고객189',
#  'C0125': '고객125',
#  'C0174': '고객174',
#  'C0157': '고객157',
#  'C0006': '고객6',
#  'C0037': '고객37'}

# %%
# 고객 네트워크 그래프 생성
G = nx.Graph()

for idx, row in df_sample.iterrows():
    cust_id = row["고객ID"]
    cust_name = row["고객이름"]
    cust_label = f"{cust_name} ({cust_id})"
    
    companion_id = row["동반인ID"]
    if pd.notnull(companion_id):
        companion_name = customer_dict.get(companion_id, companion_id)
        companion_label = f"{companion_name} ({companion_id})"
        
        G.add_node(cust_label)
        G.add_node(companion_label)
        G.add_edge(cust_label, companion_label)
        
# 중심성 분석
degree_centrality = nx.degree_centrality(G)
betweenness_centrality = nx.betweenness_centrality(G)
closeness_centrality = nx.closeness_centrality(G)

# %%
# 상위 5명 정리
top_k = 10
top_degree = sorted(degree_centrality.items(), key=lambda x: x[1], reverse=True)[:top_k]

result = []
for node,degree in top_degree:
    result.append({"고객이름(고객ID)" : node, "연결중심성(Degree)" : round(degree, 4), "매개중심성(Betweenness)" : round(betweenness_centrality.get(node, 0), 4),
                  "근접중심성(Closeness)" : round(closeness_centrality.get(node, 0), 4)})
    
df_result = pd.DataFrame(result)
df_result
# Out:
#       고객이름(고객ID)  연결중심성(Degree)  매개중심성(Betweenness)  근접중심성(Closeness)
# 0  고객106 (C0106)         0.0515              0.0713            0.3050
# 1  고객133 (C0133)         0.0464              0.0645            0.3065
# 2  고객153 (C0153)         0.0412              0.0440            0.2840
# 3  고객163 (C0163)         0.0412              0.0366            0.2904
# 4  고객100 (C0100)         0.0412              0.0531            0.2953
# 5  고객114 (C0114)         0.0412              0.0517            0.2900
# 6  고객195 (C0195)         0.0412              0.0707            0.3031
# 7   고객24 (C0024)         0.0361              0.0412            0.2866
# 8  고객170 (C0170)         0.0361              0.0331            0.2771
# 9  고객183 (C0183)         0.0361              0.0375            0.2870

# %% [markdown]
# * 연결중심성 : 직접 연결된 고객 수 비율, 동반 방문 횟수나 연결된 고객이 많을수록 높음
# * 매개중심성(Betweenness) : 다른 고객 사이의 중개 역할 비율, 다양한 고객 집단을 이어주는 다리 역할을 할수록 높음
# * 근접중심성(Closeness) : 전체 고객들과의 거리 평균의 역수, 네트워크 전체와 가깝게 연결되어 있을수록 높음

# %%
plt.rcParams["axes.unicode_minus"] = False

# 노드 속성 설정
node_colors = [degree_centrality.get(node, 0) for node in G.nodes]
node_sizes = [2000 * degree_centrality.get(node, 0) + 100 for node in G.nodes]

# 노드 위치 계산 k는 노드간의 평균거리(작으면 촘촘하게, 크면 넓게)
pos = nx.spring_layout(G, seed=42, k=0.5)

plt.figure(figsize=(14,10))
nodes = nx.draw_networkx_nodes(G, pos, node_color = node_colors, node_size = node_sizes, cmap = plt.cm.plasma)

# 엣지와 레이블
nx.draw_networkx_edges(G, pos, alpha=0.4)
nx.draw_networkx_labels(G, pos, font_size=10, font_family=font_prop.get_name())
plt.colorbar(nodes, label="연결중심성(Degree Centrality)")
plt.title("고객 동반방문 네트워크 중심성 시각화", fontproperties = font_prop, fontsize=16)
plt.axis("off")
plt.tight_layout()
plt.show()
