# %% [markdown]
# # 딥러닝 라이브러리 2가지
# ## 텐서플로우(google) - 산업용
# * 이미지 관련 라이브러리
# * keras를 이용해 코딩이 쉬움
# * 순차적, 함수적, 클래스
#
# ## 파이토치(meta) - 연구용
# * 자연어 관련 라이브러리
# * 허깅페이스, 랭체인
# * 클래스

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import koreanize_matplotlib

# %%
data = pd.read_csv("https://raw.githubusercontent.com/haram4th/ablearn/main/Taitanic_train.csv")
data.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
data = data[['Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Embarked']]

# %%
data.head(2)
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch Embarked
# 0         0       3    male  22.0      1      0        S
# 1         1       1  female  38.0      1      0        C

# %%
data['family'] = data["SibSp"] + data['Parch']
data
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch Embarked  family
# 0           0       3    male  22.0      1      0        S       1
# 1           1       1  female  38.0      1      0        C       1
# 2           1       3  female  26.0      0      0        S       0
# 3           1       1  female  35.0      1      0        S       1
# 4           0       3    male  35.0      0      0        S       0
# ..        ...     ...     ...   ...    ...    ...      ...     ...
# 886         0       2    male  27.0      0      0        S       0
# 887         1       1  female  19.0      0      0        S       0
# 888         0       3  female   NaN      1      2        S       3
# 889         1       1    male  26.0      0      0        C       0
# 890         0       3    male  32.0      0      0        Q       0
#
# [891 rows x 8 columns]

# %%
data['Age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
data.loc[:, 'Age'] = data['Age'].fillna(data['Age'].mean())
data
# Out:
#      Survived  Pclass     Sex        Age  SibSp  Parch Embarked  family
# 0           0       3    male  22.000000      1      0        S       1
# 1           1       1  female  38.000000      1      0        C       1
# 2           1       3  female  26.000000      0      0        S       0
# 3           1       1  female  35.000000      1      0        S       1
# 4           0       3    male  35.000000      0      0        S       0
# ..        ...     ...     ...        ...    ...    ...      ...     ...
# 886         0       2    male  27.000000      0      0        S       0
# 887         1       1  female  19.000000      0      0        S       0
# 888         0       3  female  29.699118      1      2        S       3
# 889         1       1    male  26.000000      0      0        C       0
# 890         0       3    male  32.000000      0      0        Q       0
#
# [891 rows x 8 columns]

# %%
data['Embarked'].mode()[0]
# Out:
# 'S'

# %%
data['Embarked'] = data['Embarked'].fillna(data['Embarked'].mode()[0])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Sex       891 non-null    object
#  3   Age       891 non-null    float64
#  4   SibSp     891 non-null    int64
#  5   Parch     891 non-null    int64
#  6   Embarked  891 non-null    object
#  7   family    891 non-null    int64
# dtypes: float64(1), int64(5), object(2)
# memory usage: 55.8+ KB

# %%
data = data.drop(['SibSp', 'Parch'], axis=1)
data
# Out:
#      Survived  Pclass     Sex        Age Embarked  family
# 0           0       3    male  22.000000        S       1
# 1           1       1  female  38.000000        C       1
# 2           1       3  female  26.000000        S       0
# 3           1       1  female  35.000000        S       1
# 4           0       3    male  35.000000        S       0
# ..        ...     ...     ...        ...      ...     ...
# 886         0       2    male  27.000000        S       0
# 887         1       1  female  19.000000        S       0
# 888         0       3  female  29.699118        S       3
# 889         1       1    male  26.000000        C       0
# 890         0       3    male  32.000000        Q       0
#
# [891 rows x 6 columns]

# %%
data = pd.get_dummies(data, drop_first=True)
data
# Out:
#      Survived  Pclass        Age  family  Sex_male  Embarked_Q  Embarked_S
# 0           0       3  22.000000       1      True       False        True
# 1           1       1  38.000000       1     False       False       False
# 2           1       3  26.000000       0     False       False        True
# 3           1       1  35.000000       1     False       False        True
# 4           0       3  35.000000       0      True       False        True
# ..        ...     ...        ...     ...       ...         ...         ...
# 886         0       2  27.000000       0      True       False        True
# 887         1       1  19.000000       0     False       False        True
# 888         0       3  29.699118       3     False       False        True
# 889         1       1  26.000000       0      True       False       False
# 890         0       3  32.000000       0      True        True       False
#
# [891 rows x 7 columns]

# %%
X = data.drop('Survived', axis=1)
y = data['Survived']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, stratify=y, random_state=42)

# %% [markdown]
# # 딥러닝시에도 데이터의 스케일을 맞춰 주는것이 좋다.
# * StandardScaler, MinMaxScaler를 주로 사용, 이상값이 많을 경우 RobustScaler를 사용
# * 이진분류(0,1): MinMaxScaler
# * 연속값예측: StandardScaler

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
mms = MinMaxScaler()
mms_X_train = mms.fit_transform(X_train)
mms_X_test = mms.transform(X_test)
mms_X_train = pd.DataFrame(mms_X_train, columns=X_train.columns, index=X_train.index)
mms_X_test = pd.DataFrame(mms_X_test, columns=X_test.columns, index=X_test.index)
display(mms_X_train)
display(mms_X_test)
# Out:
#      Pclass       Age  family  Sex_male  Embarked_Q  Embarked_S
# 748     0.0  0.233476     0.1       1.0         0.0         1.0
# 45      1.0  0.367921     0.0       1.0         0.0         1.0
# 28      1.0  0.367921     0.0       0.0         1.0         0.0
# 633     0.0  0.367921     0.0       1.0         0.0         1.0
# 403     1.0  0.346569     0.1       1.0         0.0         1.0
# ..      ...       ...     ...       ...         ...         ...
# 476     0.5  0.421965     0.1       1.0         0.0         1.0
# 190     0.5  0.396833     0.0       0.0         0.0         1.0
# 736     1.0  0.597889     0.4       0.0         0.0         1.0
# 462     0.0  0.585323     0.0       1.0         0.0         1.0
# 136     0.0  0.233476     0.2       0.0         0.0         1.0
#
# [623 rows x 6 columns]
#      Pclass       Age  family  Sex_male  Embarked_Q  Embarked_S
# 625     0.0  0.761247     0.0       1.0         0.0         1.0
# 566     1.0  0.233476     0.0       1.0         0.0         1.0
# 459     1.0  0.367921     0.0       1.0         1.0         0.0
# 804     1.0  0.334004     0.0       1.0         0.0         1.0
# 338     1.0  0.560191     0.0       1.0         0.0         1.0
# ..      ...       ...     ...       ...         ...         ...
# 184     1.0  0.044986     0.2       0.0         0.0         1.0
# 607     0.0  0.334004     0.0       1.0         0.0         1.0
# 624     1.0  0.258608     0.0       1.0         0.0         1.0
# 103     1.0  0.409399     0.0       1.0         0.0         1.0
# 387     0.5  0.447097     0.0       0.0         0.0         1.0
#
# [268 rows x 6 columns]

# %% [markdown]
# # Tensorflow Sequential API를 사용한 순차적 모델 생성 및 분석
# * Sequential: 인공신경망을 순차적으로 작성할 때 사용
# * Dense: 층, 레이어
# * 1. 신경망 모델 정의
# * 2. 신경망 모델 훈련
# * 3. 훈련된 모델로 테스트
# * 4. 검증

# %%
import tensorflow as tf
from tensorflow.keras import Input
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
# Out:
# 2025-05-14 15:38:59.197335: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-05-14 15:38:59.240734: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1747204739.272172   55964 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1747204739.283939   55964 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1747204739.318099   55964 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1747204739.318123   55964 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1747204739.318125   55964 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1747204739.318126   55964 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-05-14 15:38:59.330446: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# * 입력층은 반드시 독립변수의수(input_dim)를 정확히 지정
# * 신경망 모델의 은닉층은 2~3개 정도로 한다.
# * Dense의 노드수는 2의 배수의 지정 2 4 8 16 256
# * Dense의 노드는 큰 수에서 작은 수로 줄여나간다.
# * 은닉층의 활성화 함수: Reru
# * 출력층은 이진분류일 경우 sigmoid, 다중분류일 경우 softmax
# * 회귀분석일 경우(종속변수가 연속형(수치형)인 경우) 출력층에 활성화 함수 없이 노드를 1로 지정

# %%
mms_X_train.shape[1]
# Out:
# 6

# %%
# 신경망 모델 정의 kearas 3.0, tensorflow 2.19 기준
model = Sequential()
model.add(Input(shape=(mms_X_train.shape[1],))) # 입력층
model.add(Dense(64, activation='relu')) # 은닉층
model.add(Dense(32, activation='relu')) # 은닉층
model.add(Dense(16, activation='relu')) # 은닉층
model.add(Dense(1, activation='sigmoid')) # 출력층, 이진분류이므로 sigmoid

# %% [markdown]
# #  모델의 파라미터 세팅 model.compile()
# * loss: 오차 계산 지표
#   * 이진분류: binary_crossentropy
#   * 다중분류: categorical_crossentropy
#   * 데이터에 0이 많은 희소행렬인 경우: sparse_categorical_crossentropy
#   * 연속형데이터(회귀분석): mse
# * optimizer: learning_rate
#   * adam을 가장 많이 사용
# * metrics: 평가지표 accuracy

# %%
# 모델의 파라미터 세팅
model.compile(loss="binary_crossentropy", optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_4 (Dense)                 │ (None, 64)             │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,073 (12.00 KB)
#  Trainable params: 3,073 (12.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
len(mms_X_train)
# Out:
# 623

# %% [markdown]
# # 모델 훈련 model.fit(X_train, y_train)
# * epochs: 전체 데이터를 한 번 훈련하는 주기, 10-100 사이
# * batch_size: 전체 데이터를 쪼개서 훈련, 데이터의 묶음, 메모리에 맞춰서 크기 조절(2의 배수) 32, 64로 쪼개서 넣는 것 추천
# * validation_data: 검증 데이터로 모델 검증 실시

# %%
history = model.fit(mms_X_train, y_train, epochs=100, batch_size=16,
                    validation_data=(mms_X_test, y_test))
# Out:
# Epoch 1/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - accuracy: 0.7366 - loss: 0.6161 - val_accuracy: 0.7761 - val_loss: 0.5496
# Epoch 2/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7630 - loss: 0.5229 - val_accuracy: 0.7799 - val_loss: 0.5061
# Epoch 3/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7965 - loss: 0.4781 - val_accuracy: 0.7761 - val_loss: 0.4876
# Epoch 4/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8055 - loss: 0.4827 - val_accuracy: 0.7761 - val_loss: 0.4727
# Epoch 5/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7926 - loss: 0.4577 - val_accuracy: 0.8060 - val_loss: 0.4594
# Epoch 6/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8120 - loss: 0.4369 - val_accuracy: 0.8209 - val_loss: 0.4604
# Epoch 7/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7750 - loss: 0.4982 - val_accuracy: 0.8172 - val_loss: 0.4462
# Epoch 8/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8195 - loss: 0.4348 - val_accuracy: 0.7985 - val_loss: 0.4425
# Epoch 9/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ -0s -4454us/step - accuracy: 0.8063 - loss: 0.4241 - val_accuracy: 0.8060 - val_loss: 0.4363
# Epoch 10/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ -0s -6623us/step - accuracy: 0.7940 - loss: 0.4368 - val_accuracy: 0.8134 - val_loss: 0.4324
# Epoch 11/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8446 - loss: 0.3872 - val_accuracy: 0.8134 - val_loss: 0.4290
# Epoch 12/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8136 - loss: 0.4436 - val_accuracy: 0.8022 - val_loss: 0.4277
# Epoch 13/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7968 - loss: 0.4315 - val_accuracy: 0.8172 - val_loss: 0.4249
# Epoch 14/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8175 - loss: 0.4290 - val_accuracy: 0.8134 - val_loss: 0.4238
# Epoch 15/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8105 - loss: 0.4179 - val_accuracy: 0.8060 - val_loss: 0.4242
# Epoch 16/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.
100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8360 - loss: 0.4094 - val_accuracy: 0.7836 - val_loss: 0.4540
# Epoch 83/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8497 - loss: 0.3847 - val_accuracy: 0.8209 - val_loss: 0.4317
# Epoch 84/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8438 - loss: 0.3839 - val_accuracy: 0.7799 - val_loss: 0.4471
# Epoch 85/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8314 - loss: 0.3918 - val_accuracy: 0.8060 - val_loss: 0.4350
# Epoch 86/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8460 - loss: 0.3859 - val_accuracy: 0.8246 - val_loss: 0.4329
# Epoch 87/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8150 - loss: 0.4161 - val_accuracy: 0.7985 - val_loss: 0.4347
# Epoch 88/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8392 - loss: 0.4069 - val_accuracy: 0.8097 - val_loss: 0.4326
# Epoch 89/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8525 - loss: 0.3612 - val_accuracy: 0.8172 - val_loss: 0.4309
# Epoch 90/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8579 - loss: 0.3554 - val_accuracy: 0.8246 - val_loss: 0.4326
# Epoch 91/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8446 - loss: 0.3828 - val_accuracy: 0.8060 - val_loss: 0.4429
# Epoch 92/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8480 - loss: 0.3812 - val_accuracy: 0.8172 - val_loss: 0.4400
# Epoch 93/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8572 - loss: 0.3646 - val_accuracy: 0.7910 - val_loss: 0.4484
# Epoch 94/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8453 - loss: 0.3873 - val_accuracy: 0.8209 - val_loss: 0.4354
# Epoch 95/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8403 - loss: 0.3470 - val_accuracy: 0.8097 - val_loss: 0.4400
# Epoch 96/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8427 - loss: 0.3799 - val_accuracy: 0.8246 - val_loss: 0.4362
# Epoch 97/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8473 - loss: 0.3831 - val_accuracy: 0.8060 - val_loss: 0.4434
# Epoch 98/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8030 - loss: 0.4176 - val_accuracy: 0.8172 - val_loss: 0.4362
# Epoch 99/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8602 - loss: 0.3596 - val_accuracy: 0.7985 - val_loss: 0.4534
# Epoch 100/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8487 - loss: 0.3680 - val_accuracy: 0.7985 - val_loss: 0.4500

# %% [markdown]
# # 딥러닝 모델 성능 평가
# * 딥러닝에서 모델의 성능을 평가하는 지표는 loss
# * 보통 loss가 낮으면 accuracy가 올라가지만 비례하지 않을 때도 있음.
# * accuracy와 loss 간의 차이가 있을 때 loss가 낮은 모델이 우수한 모델

# %%
score = model.evaluate(mms_X_test, y_test)
print('test loss', score[0])
print('test accuracy', score[1])
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8110 - loss: 0.4402
# test loss 0.45001158118247986
# test accuracy 0.7985074520111084

# %%
for i in history.history:
    print(i)
# Out:
# accuracy
# loss
# val_accuracy
# val_loss

# %% [markdown]
# # 훈련 결과 시각화하기 history.history['loss'], history.history['val_loss']

# %%
plt.figure(figsize=(8,5))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend(['train', 'val'])
plt.show()

# %% [markdown]
# # 모델의 예측 값 출력

# %%
pred = model.predict(mms_X_test)
pred
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# array([[0.3224107 ],
#        [0.16627666],
#        [0.13846901],
#        [0.13033496],
#        [0.07669833],
#        [0.54526645],
#        [0.1165498 ],
#        [0.86403495],
#        [0.11942178],
#        [0.95446765],
#        [0.8548511 ],
#        [0.9879759 ],
#        [0.38475385],
#        [0.32286507],
#        [0.84194374],
#        [0.8721963 ],
#        [0.13846901],
#        [0.37331095],
#        [0.9401576 ],
#        [0.32355034],
#        [0.06949241],
#        [0.08921746],
#        [0.56245553],
#        [0.13033496],
#        [0.30915934],
#        [0.1769368 ],
#        [0.97151214],
#        [0.3073617 ],
#        [0.26667657],
#        [0.2872348 ],
#        [0.92226344],
#        [0.9567568 ],
#        [0.13846901],
#        [0.8756473 ],
#        [0.98629975],
#        [0.58309454],
#        [0.13846901],
#        [0.05862527],
#        [0.13846901],
#        [0.3281903 ],
#        [0.1165498 ],
#        [0.9676826 ],
#        [0.6592424 ],
#        [0.98435545],
#        [0.9882578 ],
#        [0.17230731],
#        [0.56971455],
#        [0.28262472],
#        [0.83504003],
#        [0.12049659],
#        [0.07120336],
#        [0.07715765],
#        [0.38475385],
#        [0.5701883 ],
#        [0.15016861],
#        [0.13404472],
#        [0.12049659],
#        [0.32149857],
#        [0.4554264 ],
#        [0.06910704],
#        [0.12049659],
#        [0.16627666],
#        [0.13793942],
#        [0.91655314],
#        [0.07296285],
#        [0.19132155],
#        [0.15442209],
#        [0.901167  ],
#        [0.1071827 ],
#        [0.13110884],
#        [0.990698  ],
#        [0.4786131 ],
#        [0.1341023 ],
#        [0.93494284],
#        [0.13806926],
#        [0.15880452],
#        [0.45249307],
#        [0.13404472],
#        [0.13416377],
#        [0.12475228],
#        [0.3738457 ],
#        [0.98435545],
#        [0.985743  ],
#        [0.29962713],
#        [0.13157035],
#        [0.13033496],
#        [0.5156384 ],
#        [0.9744338 ],
#        [0.42598125],
#        [0.06217244],
#        [0.9859973 ],
#        [0.12477741],
#        [0.22107503],
#        [0.32440537],
#        [0.32149857],
#        [0.9641071 ],
#        [0.9444816 ],
#        [0.69958675],
#        [0.13846901],
#        [0.12049659],
#        [0.45703846],
#        [0.91726667],
#        [0.9864243 ],
#        [0.9871901 ],
#        [0.08708607],
#        [0.08056139],
#        [0.9188977 ],
#        [0.07058772],
#        [0.31549123],
#        [0.17867723],
#        [0.15880452],
#        [0.3305205 ],
#        [0.09947835],
#        [0.35329124],
#        [0.0394154 ],
#        [0.12049659],
#        [0.6280813 ],
#        [0.67327505],
#        [0.8918365 ],
#        [0.90308213],
#        [0.12167594],
#        [0.8721963 ],
#        [0.3291393 ],
#        [0.09315756],
#        [0.8798303 ],
#        [0.97335297],
#        [0.32355034],
#        [0.6592424 ],
#        [0.96405035],
#        [0.1165498 ],
#        [0.5966456 ],
#        [0.7998313 ],
#        [0.9423641 ],
#        [0.15880452],
#        [0.9783967 ],
#        [0.88422406],
#        [0.28353772],
#        [0.8548511 ],
#        [0.58629876],
#        [0.90531474],
#        [0.2105059 ],
#        [0.99039173],
#        [0.12049659],
#        [0.32286507],
#        [0.46224165],
#        [0.15831491],
#        [0.90859383],
#        [0.98435545],
#        [0.12049659],
#        [0.1165498 ],
#        [0.12583238],
#        [0.3311957 ],
#        [0.93730867],
#        [0.15442209],
#        [0.1470246 ],
#        [0.08329757],
#        [0.15880452],
#        [0.37771282],
#        [0.12659533],
#        [0.42598125],
#        [0.7403836 ],
#        [0.28341207],
#        [0.957705  ],
#        [0.35878208],
#        [0.1769368 ],
#        [0.6082166 ],
#        [0.05942562],
#        [0.20114309],
#        [0.8548511 ],
#        [0.9922091 ],
#        [0.08329757],
#        [0.68832123],
#        [0.1334588 ],
#        [0.11520876],
#        [0.9855364 ],
#        [0.6887083 ],
#        [0.29345655],
#        [0.16479327],
#        [0.7998313 ],
#        [0.8981557 ],
#        [0.32149857],
#        [0.9856442 ],
#        [0.8275748 ],
#        [0.12296798],
#        [0.1769368 ],
#        [0.9857534 ],
#        [0.12049659],
#        [0.13994995],
#        [0.4935517 ],
#        [0.9032886 ],
#        [0.13794032],
#        [0.12049659],
#        [0.52044743],
#        [0.9123193 ],
#        [0.13846901],
#        [0.4713181 ],
#        [0.93838173],
#        [0.18769738],
#        [0.58420545],
#        [0.46224165],
#        [0.7165047 ],
#        [0.66153157],
#        [0.0786069 ],
#        [0.12049659],
#        [0.98743   ],
#        [0.14606829],
#        [0.98420566],
#        [0.42114305],
#        [0.10947282],
#        [0.03463329],
#        [0.52044743],
#        [0.25468603],
#        [0.26235667],
#        [0.9824291 ],
#        [0.1341023 ],
#        [0.11772145],
#        [0.02921378],
#        [0.32521904],
#        [0.28341207],
#        [0.32355034],
#        [0.30775335],
#        [0.13846901],
#        [0.12296798],
#        [0.12049659],
#        [0.51061726],
#        [0.9601118 ],
#        [0.13794032],
#        [0.10498498],
#        [0.4638384 ],
#        [0.18777785],
#        [0.10316306],
#        [0.19132155],
#        [0.098193  ],
#        [0.42598125],
#        [0.9279267 ],
#        [0.32945067],
#        [0.6130751 ],
#        [0.7998313 ],
#        [0.5871479 ],
#        [0.12484168],
#        [0.07169351],
#        [0.10316306],
#        [0.10942253],
#        [0.106259  ],
#        [0.1341023 ],
#        [0.01893847],
#        [0.975753  ],
#        [0.10051894],
#        [0.22744751],
#        [0.32149857],
#        [0.932899  ],
#        [0.8548511 ],
#        [0.45513496],
#        [0.18925947],
#        [0.98205954],
#        [0.9917646 ],
#        [0.32747474],
#        [0.9658802 ],
#        [0.12659533],
#        [0.5088476 ],
#        [0.5156384 ],
#        [0.45472133],
#        [0.13846901],
#        [0.89599776],
#        [0.32486624],
#        [0.15442209],
#        [0.10942253],
#        [0.9153703 ]], dtype=float32)

# %%
result = pd.DataFrame(dict(y_test=y_test, pred=pred[:,0]))
result
# Out:
#      y_test      pred
# 625       0  0.322411
# 566       0  0.166277
# 459       0  0.138469
# 804       1  0.130335
# 338       1  0.076698
# ..      ...       ...
# 184       1  0.895998
# 607       1  0.324866
# 624       0  0.154422
# 103       0  0.109423
# 387       1  0.915370
#
# [268 rows x 2 columns]

# %%
result['pred'] = result['pred'].apply(lambda x: 1 if x >= 0.5 else 0)
result
# Out:
#      y_test  pred
# 625       0     0
# 566       0     0
# 459       0     0
# 804       1     0
# 338       1     0
# ..      ...   ...
# 184       1     1
# 607       1     0
# 624       0     0
# 103       0     0
# 387       1     1
#
# [268 rows x 2 columns]

# %%
from sklearn.metrics import classification_report
print(classification_report(result['y_test'], result['pred']))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.85      0.84       165
#            1       0.75      0.72      0.73       103
#
#     accuracy                           0.80       268
#    macro avg       0.79      0.78      0.79       268
# weighted avg       0.80      0.80      0.80       268

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtc = DecisionTreeClassifier(max_depth=3, random_state=42)
dtc.fit(mms_X_train, y_train)
pred2 = dtc.predict(mms_X_test)
print(classification_report(y_test, pred2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.88      0.85       165
#            1       0.78      0.69      0.73       103
#
#     accuracy                           0.81       268
#    macro avg       0.80      0.78      0.79       268
# weighted avg       0.80      0.81      0.80       268

# %% [markdown]
# # Functional API를 이용한 함수형 모델
# * Sequential API는 단순히 층을 여러 개 쌓는 형태라 복잡한 모델 생성에 한계가 있음.
# * Functional  API는 입력층과 출력층을 사용자가 직접 정의 가능
# * 다중입력(Multi-input), 다중출력(Multi-output)등 복잡한 모델을 정의 할 수 있음.
# * Input(shape=(독립변수 수))로 입력층 정의
# * 이전 층을 다음 층의 입력으로 사용
# * model()에 입력과 출력을 정의

# %%
# tensorflow 2.19버전용
from keras.layers import Input, Dense
from keras.models import Model

# %%
# 입력층
inputs = Input(shape=(mms_X_train.shape[1],))

# 은닉층
x = Dense(64, activation='relu')(inputs)
x = Dense(32, activation='relu')(x)
x = Dense(16, activation='relu')(x)

# 출력층
outputs = Dense(1, activation='sigmoid')(x)

# 모델 정의
model = Model(inputs=inputs, outputs=outputs)
model.summary()
# Out:
# Model: "functional_8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)      │ (None, 6)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 64)             │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,073 (12.00 KB)
#  Trainable params: 3,073 (12.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
history = model.fit(mms_X_train, y_train, epochs=100,
                    batch_size=32,
                    validation_data=(mms_X_test, y_test))
pred = model.predict(mms_X_test)
pred = pd.DataFrame(pred)
pred = pred[0].apply(lambda x: 1 if x > 0.5 else 0)
print(classification_report(y_test, pred))
plt.figure(figsize=(8,5))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend(['train', 'val'])
plt.show()
# Out:
# Epoch 1/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - accuracy: 0.4831 - loss: 0.6878 - val_accuracy: 0.6306 - val_loss: 0.6455
# Epoch 2/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6695 - loss: 0.6236 - val_accuracy: 0.6530 - val_loss: 0.5909
# Epoch 3/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6657 - loss: 0.5744 - val_accuracy: 0.7351 - val_loss: 0.5469
# Epoch 4/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7769 - loss: 0.5091 - val_accuracy: 0.7761 - val_loss: 0.5137
# Epoch 5/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7980 - loss: 0.4821 - val_accuracy: 0.7761 - val_loss: 0.4877
# Epoch 6/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7851 - loss: 0.4829 - val_accuracy: 0.7985 - val_loss: 0.4732
# Epoch 7/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8044 - loss: 0.4650 - val_accuracy: 0.7836 - val_loss: 0.4636
# Epoch 8/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7843 - loss: 0.4739 - val_accuracy: 0.8172 - val_loss: 0.4564
# Epoch 9/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8157 - loss: 0.4496 - val_accuracy: 0.7687 - val_loss: 0.4547
# Epoch 10/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7702 - loss: 0.4702 - val_accuracy: 0.8134 - val_loss: 0.4452
# Epoch 11/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8040 - loss: 0.4455 - val_accuracy: 0.8172 - val_loss: 0.4419
# Epoch 12/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8288 - loss: 0.4239 - val_accuracy: 0.7873 - val_loss: 0.4415
# Epoch 13/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8291 - loss: 0.4032 - val_accuracy: 0.8172 - val_loss: 0.4349
# Epoch 14/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8023 - loss: 0.4542 - val_accuracy: 0.8209 - val_loss: 0.4343
# Epoch 15/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8200 - loss: 0.4153 - val_accuracy: 0.8209 - val_loss: 0.4320
# Epoch 16/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7914 - loss: 0.4683 - val_accuracy: 0.8172 - val_loss: 0.4312
# Epoch 17/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8207 - loss: 0.4194 - val_accuracy: 0.8097 - val_loss: 0.4291
# Epoch 18/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8209 - loss: 0.4288 - val_accuracy: 0.8209 - val_loss: 0.4277
# Epoch 19/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8056 - loss: 0.4328 - val_accuracy: 0.7873 - val_loss: 0.4305
# Epoch 20/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8036 - loss: 0.4390 - val_accuracy: 0.8172 - val_loss: 0.4257
# Epoch 21/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8278 - loss: 0.4257 - val_accuracy: 0.8097 - val_loss: 0.4249
# Epoch 22/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8031 - loss: 0.4397 - val_accuracy: 0.8097 - val_loss: 0.4366
# Epoch 23/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7759 - loss: 0.4500 - val_accuracy: 0.8134 - val_loss: 0.4242
# Epoch 24/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8244 - loss: 0.4174 - val_accuracy: 0.7836 - val_loss: 0.4261
# Epoch 25/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
#               precision    recall  f1-score   support
#
#            0       0.81      0.89      0.85       165
#            1       0.79      0.66      0.72       103
#
#     accuracy                           0.80       268
#    macro avg       0.80      0.78      0.78       268
# weighted avg       0.80      0.80      0.80       268

# %% [markdown]
# # class형으로 만들기 (Model Subclass API)
# * class 형태의 모델 정의 방법
# * keras의 Model을 상속받아 작성

# %%
class Titanic(Model):
    def __init__(self):
        super(Titanic, self).__init__()
        self.dense1 = Dense(128, activation='relu')
        self.dense2 = Dense(64, activation='relu')
        self.dense3 = Dense(32, activation='relu')
        self.dense4 = Dense(16, activation='relu')
        self.classifier = Dense(1, activation='sigmoid')
    
    def call(self, inputs):
        x = self.dense1(inputs)
        x = self.dense2(x)
        x = self.dense3(x)
        x = self.dense4(x)
        return self.classifier(x)

# %%
model = Titanic()
print(model.summary())
# Out:
# Model: "titanic"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_12 (Dense)                │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_14 (Dense)                │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_15 (Dense)                │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_16 (Dense)                │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)
# None

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
history = model.fit(mms_X_train, y_train, epochs=100, 
                    batch_size=32, validation_data=(mms_X_test, y_test))
pred = model.predict(mms_X_test)
pred = pd.DataFrame(pred)
pred = pred[0].apply(lambda x: 1 if x > 0.5 else 0)
print(classification_report(y_test, pred))
plt.figure(figsize=(8,5))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend(['train', 'val'])
plt.show()
# Out:
# Epoch 1/100
# 2025-05-14 17:01:58.975792: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_193', 12 bytes spill stores, 12 bytes spill loads
#
# 2025-05-14 17:01:59.007666: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_193', 4 bytes spill stores, 4 bytes spill loads
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 6s 156ms/step - accuracy: 0.6342 - loss: 0.6308 - val_accuracy: 0.6567 - val_loss: 0.5725
# Epoch 2/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7556 - loss: 0.5179 - val_accuracy: 0.7761 - val_loss: 0.5204
# Epoch 3/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7973 - loss: 0.5022 - val_accuracy: 0.7799 - val_loss: 0.4835
# Epoch 4/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8170 - loss: 0.4390 - val_accuracy: 0.7724 - val_loss: 0.4678
# Epoch 5/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7584 - loss: 0.4894 - val_accuracy: 0.8134 - val_loss: 0.4503
# Epoch 6/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7774 - loss: 0.4703 - val_accuracy: 0.8209 - val_loss: 0.4666
# Epoch 7/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8318 - loss: 0.4255 - val_accuracy: 0.7761 - val_loss: 0.4544
# Epoch 8/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8132 - loss: 0.4359 - val_accuracy: 0.8134 - val_loss: 0.4342
# Epoch 9/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8051 - loss: 0.4434 - val_accuracy: 0.8097 - val_loss: 0.4312
# Epoch 10/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8172 - loss: 0.4300 - val_accuracy: 0.8060 - val_loss: 0.4298
# Epoch 11/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8278 - loss: 0.4022 - val_accuracy: 0.7910 - val_loss: 0.4453
# Epoch 12/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8037 - loss: 0.4410 - val_accuracy: 0.8172 - val_loss: 0.4251
# Epoch 13/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7944 - loss: 0.4654 - val_accuracy: 0.8134 - val_loss: 0.4325
# Epoch 14/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8414 - loss: 0.3992 - val_accuracy: 0.7985 - val_loss: 0.4474
# Epoch 15/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8142 - loss: 0.4189 - val_accuracy: 0.8134 - val_loss: 0.4290
# Epoch 16/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8270 - loss: 0.4066 - val_accuracy: 0.8209 - val_loss: 0.4261
# Epoch 17/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8332 - loss: 0.3853 - val_accuracy: 0.7873 - val_loss: 0.4516
# Epoch 18/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8113 - loss: 0.4202 - val_accuracy: 0.8172 - val_loss: 0.4298
# Epoch 19/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8034 - loss: 0.4315 - val_accuracy: 0.8172 - val_loss: 0.4267
# Epoch 20/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8299 - loss: 0.4278 - val_accuracy: 0.8284 - val_loss: 0.4257
# Epoch 21/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8312 - loss: 0.4120 - val_accuracy: 0.8022 - val_loss: 0.4329
# Epoch 22/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8257 - loss: 0.4022 - val_accuracy: 0.8134 - val_loss: 0.4252
# Epoch 23/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8414 - loss: 0.3892 - val_accuracy: 0.7873 - val_loss: 0.4362
# Epoch 24/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8025 - loss: 0.4201 - val_accuracy: 0.8172 - val_loss: 0.4251
# Epoch 25/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8425 - loss: 0.3937 - val_accuracy: 0.8060 - val_loss: 0.4212
# Epoch 26/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8258 - loss: 0.4216 - val_accuracy: 0.7910 - val_loss: 0.4238
# Epoch 27/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.